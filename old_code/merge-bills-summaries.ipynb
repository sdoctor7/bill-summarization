# %%
import xmltodict
import pandas as pd
import os
import re

# %%
billDir = 'data/bills' 
summariesDir = 'data/summaries'

# %% [markdown]
# ### First Way to Merge

# %%
def getBillFileName(summaryFileName, extension):
    """
    Return bill file names based on summaryfilenames
    """
#     US_Bill_Text_115_HR1607_IH.xml <- US_Bill_Digest_115_hr_1607.xml
#     possibleExt = ["_RH.xml","_IH.xml","_EH.xml","_RFS.xml","_IS.xml"]
    billFileName = []
    if summaryFileName.startswith("US_Bill_Digest_115_"):
        tempFile = summaryFileName.split("_")
        tempFile = tempFile[-2:]
        tempFile[0] = tempFile[0].upper()
        for ext in extension:
            billFileName.append("US_Bill_Text_115_"+tempFile[0]+tempFile[1][:-4]+"_"+ext)
    return billFileName

# %%
# def print_head(d,top=10):
#     count = 0
#     for k in d:
#         if count==top:
#             break
#         print ("{} -> {}".format(k,d[k]))
#         count+=1
#     return

# %%
def getBillsToSummaries(billDir, summariesDir):

    billFiles = set()
    extension = set()
    for root, dirs, filenames in os.walk(billDir):
        for filename in filenames:
            billFiles.add(filename)
            extension.add(filename.split("_")[-1])
    assert len(billFiles)==8039
    
    billsToSummary = {}
    summariesNoMatch = set()
    for root, dirs, filenames in os.walk(summariesDir):
        for filename in filenames:
            billFileList = getBillFileName(filename, extension)
            flag = 1
            for billF in billFileList:
                if billF in billFiles:
                    billsToSummary[billF] = filename
                    flag=0
            if flag:
                summariesNoMatch.add(filename)
    return billsToSummary, billFiles, summariesNoMatch

# %%
billsToSummary, billFiles, summariesNoMatch = getBillsToSummaries(billDir, summariesDir)

# %%
print("Total Number of Bills {}".format(len(billFiles)))
print("Bills with summary {}".format(len(billsToSummary)))
print("Summaries with no bill {}".format(len(summariesNoMatch)))
# Out:
# Total Number of Bills 8039
# Bills with summary 7954
# Summaries with no bill 2298

# %%
bills = pd.read_pickle('data/bills.pkl')
summaries = pd.read_pickle('data/summaries.pkl')

# %%
index = ["fileName-Bill", "Bill-Body", "fileName-Summary","summary0", "summary1","summary2","summary3", "summary4"]
data = []

for bill_file in billsToSummary:
    summary_file = billsToSummary[bill_file]
    bill_body = bills.loc[bills['file-name'] == bill_file]['body.section'].values[0]
    summary_body0 = summaries.loc[summaries['fileName'] == summary_file]['summary0'].values[0]
    summary_body1 = summaries.loc[summaries['fileName'] == summary_file]['summary1'].values[0]
    summary_body2 = summaries.loc[summaries['fileName'] == summary_file]['summary2'].values[0]
    summary_body3 = summaries.loc[summaries['fileName'] == summary_file]['summary3'].values[0]
    summary_body4 = summaries.loc[summaries['fileName'] == summary_file]['summary4'].values[0]
    data.append((bill_file,bill_body, summary_file,summary_body0,summary_body1,summary_body2,summary_body3,summary_body4))

# %%
matched = pd.DataFrame(data, columns=index)
matched.shape
# Out:
# (7954, 8)

# %%
matched.head()
# Out:
#                      fileName-Bill  \
# 0  US_Bill_Text_115_SRES212_IS.xml
# 1   US_Bill_Text_115_HR1812_IH.xml
# 2   US_Bill_Text_115_HR1317_IH.xml
# 3    US_Bill_Text_115_S1129_RS.xml
# 4    US_Bill_Text_115_HR908_IH.xml
#
#                                            Bill-Body  \
# 0  That the Senate— (1) supports the rights, free...
# 1  1. Short title Congressional Leadership In Mit...
# 2  1. Short title Servicemember Retirement Improv...
# 3  1. Short title; table of contents (a) Short ti...
# 4  1. Short title Medicare Advantage Quality Paym...
#
#                   fileName-Summary  \
# 0  US_Bill_Digest_115_sres_212.xml
# 1   US_Bill_Digest_115_hr_1812.xml
# 2   US_Bill_Digest_115_hr_1317.xml
# 3    US_Bill_Digest_115_s_1129.xml
# 4    US_Bill_Digest_115_hr_908.xml
#
#                                             summary0 summary1 summary2  \
# 0                                                NaN      NaN      NaN
# 1  Congressional Leadership In Mitigating Adminis...      NaN      NaN
# 2  Servicemember Retirement Improvement Act  This...      NaN      NaN
# 3                                                NaN      NaN      NaN
# 4  Medicare Advantage Quality Payment Relief Act ...      NaN      NaN
#
#   summary3 summary4
# 0      NaN      NaN
# 1      NaN      NaN
# 2      NaN      NaN
# 3      NaN      NaN
# 4      NaN      NaN

# %%
matched.to_pickle('data/matched.pkl')

# %% [markdown]
# ### Another Way to Merge

# %%
bills_sel = bills[['file-name', 'bill-type', 'legis-type', 'body.section', 'section', 'sentence', 'word']]
summaries_sel = summaries[['fileName', 'sentence0', 'sentence1','sentence2', 'sentence3', 'sentence4', 
                              'summary0', 'summary1','summary2', 'summary3', 'summary4',
                              'word0', 'word1', 'word2', 'word3', 'word4']]

temp_files = []
for file in bills_sel['file-name']:
    try:
        temp_files.append(billsToSummary[file])
    except:
        temp_files.append(None)

bills_sel = bills_sel.copy()
bills_sel["fileName-Summary"] = pd.Series(temp_files, index = bills_sel.index)
matched2 = bills_sel.merge(summaries_sel, how = 'left', left_on = ['fileName-Summary'], 
                           right_on = ['fileName'], indicator = True)
matched2 = (matched2[matched2._merge == 'both']).drop(['_merge'], axis = 1)

# %%
matched2.to_pickle('data/matched2.pkl')

# %% [markdown]
# ### Third Way to Merge

# %%
def get_bill_info(row):
    if row['legis-num']:
        splitted = row['legis-num'].split('. ')
        billType = None
        billNum = splitted[-1]
        if len(splitted) > 2:
            billType = ''.join(splitted[:-1])
        else:
            billType = splitted[0]
        return ' '.join([billType, billNum])
    else:
        return None

# %%
bills['billInfo'] = bills.apply(lambda row: get_bill_info(row), axis=1)

# %%
bills
# Out:
#        bill-type body.amendment body.division  \
# 0           bill            NaN           NaN
# 1     resolution            NaN           NaN
# 2     resolution            NaN           NaN
# 3     resolution            NaN           NaN
# 4     resolution            NaN           NaN
# 5     resolution            NaN           NaN
# 6     resolution            NaN           NaN
# 7     resolution            NaN           NaN
# 8     resolution            NaN           NaN
# 9     resolution            NaN           NaN
# 10    resolution            NaN           NaN
# 11    resolution            NaN           NaN
# 12    resolution            NaN           NaN
# 13    resolution            NaN           NaN
# 14    resolution            NaN           NaN
# 15    resolution            NaN           NaN
# 16    resolution            NaN           NaN
# 17    resolution            NaN           NaN
# 18    resolution            NaN           NaN
# 19    resolution            NaN           NaN
# 20    resolution            NaN           NaN
# 21    resolution            NaN           NaN
# 22    resolution            NaN           NaN
# 23    resolution            NaN           NaN
# 24    resolution            NaN           NaN
# 25    resolution            NaN           NaN
# 26    resolution            NaN           NaN
# 27    resolution            NaN           NaN
# 28    resolution            NaN           NaN
# 29    resolution            NaN           NaN
# ...          ...            ...           ...
# 8009  resolution            NaN           NaN
# 8010  resolution            NaN           NaN
# 8011  resolution            NaN           NaN
# 8012  resolution            NaN           NaN
# 8013  resolution            NaN           NaN
# 8014  resolution            NaN           NaN
# 8015  resolution            NaN           NaN
# 8016  resolution            NaN           NaN
# 8017  resolution            NaN           NaN
# 8018  resolution            NaN           NaN
# 8019  resolution            NaN           NaN
# 8020  resolution            NaN           NaN
# 8021  resolution            NaN           NaN
# 8022  resolution            NaN           NaN
# 8023  resolution            NaN           NaN
# 8024  resolution            NaN           NaN
# 8025  resolution            NaN           NaN
# 8026  resolution            NaN           NaN
# 8027  resolution            NaN           NaN
# 8028  resolution            NaN           NaN
# 8029  resolution            NaN           NaN
# 8030  resolution            NaN           NaN
# 8031  resolution            NaN           NaN
# 8032  resolution            NaN           NaN
# 8033  resolution            NaN           NaN
# 8034  resolution            NaN           NaN
# 8035  resolution            NaN           NaN
# 8036  resolution            NaN           NaN
# 8037  resolution            NaN           NaN
# 8038  resolution            NaN           NaN
#
#                                            body.section body.title  \
# 0     1. Permanent resident status for Joseph\n\t\t\...        NaN
# 1     That it is the sense of Congress that— (1) the...        NaN
# 2     That it is the sense of Congress that— (1) the...        NaN
# 3     That Congress— (1) supports the designation of...        NaN
# 4     That Congress should not impose any new perfor...        NaN
# 5     1. Short title This resolution may be cited as...        NaN
# 6     That— (1) Donald J. Trump won the 2016 preside...        NaN
# 7     That it is the sense of Congress that— (1) a c...        NaN
# 8     That— 1. Short title This resolution may be ci...        NaN
# 9     1. Use of rotunda for holocaust days of rememb...        NaN
# 10    1. Use of rotunda for holocaust days of rememb...        NaN
# 11    1. Use of rotunda for holocaust days of rememb...        NaN
# 12    1. Use of rotunda for holocaust days of rememb...        NaN
# 13    That it is the sense of Congress that the Secr...        NaN
# 14    That pursuant to clause 4, section 5, article ...        NaN
# 15    That pursuant to clause 4, section 5, article ...        NaN
# 16    That it is the sense of Congress that— (1) tho...        NaN
# 17    That the House of Representatives— (1) reaffir...        NaN
# 18    That Congress recognizes— (1) the difficult ch...        NaN
# 19    That the two Houses of Congress assemble in th...        NaN
# 20    That the two Houses of Congress assemble in th...        NaN
# 21    That the two Houses of Congress assemble in th...        NaN
# 22    1. Establishment There is hereby established i...        NaN
# 23    That it is the sense of Congress that— (1) the...        NaN
# 24    That it is the sense of Congress that the Spac...        NaN
# 25    That it is the sense of Congress that America’...        NaN
# 26    1. Establishment of Committee (a) Establishmen...        NaN
# 27    That Congress supports efforts to— (1) increas...        NaN
# 28    1. Short title This concurrent resolution may ...        NaN
# 29    That Congress— (1) recognizes the 75th Anniver...        NaN
# ...                                                 ...        ...
# 8009  That the Senate— (1) designates March 2, 2017,...        NaN
# 8010  That the following shall constitute the majori...        NaN
# 8011  That the Senate— (1) designates March 3, 2017,...        NaN
# 8012  That the Senate— (1) extends warm congratulati...        NaN
# 8013  That the Senate— (1) extends warm congratulati...        NaN
# 8014  That the Senate— (1) congratulates the Johns H...        NaN
# 8015  That it is the sense of the Senate that— (1) t...        NaN
# 8016  That it is the sense of the Senate that— (1) t...        NaN
# 8017  That the Senate— (1) supports the goals of Int...        NaN
# 8018  That the Senate— (1) recognizes that March 9, ...        NaN
# 8019  That the Senate— (1) encourages the people of ...        NaN
# 8020  That the Senate— (1) strongly condemns the reg...        NaN
# 8021  That it is the sense of the Senate that— (1) t...        NaN
# 8022  That the Senate— (1) supports— (A) the designa...        NaN
# 8023  That the following shall constitute the minori...        NaN
# 8024  That the Senate— (1) affirms that the United S...        NaN
# 8025  That the Senate— (1) supports the goals and id...        NaN
# 8026  that the Senate— (1) expresses its ongoing con...        NaN
# 8027  That the Senate— (1) congratulates the Europea...        NaN
# 8028  That the Senate— (1) designates March 2017 as ...        NaN
# 8029  That the Senate— (1) designates March 2017 as ...        NaN
# 8030  That the Senate— (1) designates March 22, 2017...        NaN
# 8031  That the Senate— (1) designates March 22, 2017...        NaN
# 8032  That the Senate— (1) designates March 25, 2017...        NaN
# 8033  That a collection of the rules of the committe...        NaN
# 8034  That the Senate— (1) designates the first week...        NaN
# 8035  That the Senate— (1) designates the first week...        NaN
# 8036  That the Senate, on behalf of the United State...        NaN
# 8037  That the Senate— (1) honors the extraordinary ...        NaN
# 8038  That the Senate— (1) honors the extraordinary ...        NaN
#
#                                                dc:title  \
# 0     115 S556 IS: For the relief of Joseph Gabra an...
# 1     115 HCON 10 IH: Expressing the sense of the Co...
# 2     115 HCON 11 IH: Expressing the sense of Congre...
# 3     115 HCON 12 IH: Supporting the designation of ...
# 4     115 HCON 13 IH: Supporting the Local Radio Fre...
# 5     115 HCON 14 IH: Establishing the Joint Ad Hoc ...
# 6     115 HCON 15 IH: Asserting that Congress should...
# 7     115 HCON 16 IH: Expressing the sense of Congre...
# 8     115 HCON 17 IH: Honoring and praising the Nati...
# 9     115 HCON 18 EH: Permitting the use of the rotu...
# 10    HCON 18 ENR: Permitting the use of the rotunda...
# 11                                                 None
# 12    115 HCON 18 : Permitting the use of the rotund...
# 13    115 HCON 19 IH: Expressing the sense of Congre...
# 14    115 HCON 1 EH: Regarding consent to assemble o...
# 15    115 HCON 1 : Regarding consent to assemble out...
# 16    115 HCON 20 IH: Expressing the sense of the Ho...
# 17    115 HCON 21 IH: Reaffirming a strong commitmen...
# 18    115 HCON 22 IH: Recognizing the difficult chal...
# 19    115 HCON 23 EH: Providing for a joint session ...
# 20    HCON 23 ENR: Providing for a joint session of ...
# 21    115 HCON 23 : Providing for a joint session of...
# 22    115 HCON 24 IH: Establishing a Joint Committee...
# 23    115 HCON 25 IH: Expressing the sense of Congre...
# 24    115 HCON 26 IH: To express the sense of Congre...
# 25                                                 None
# 26    115 HCON 28 IH: Establishing a Joint Committee...
# 27    115 HCON 29 IH: Expressing the sense of the Co...
# 28    115 HCON 2 IH: To authorize the use of United ...
# 29    115 HCON 30 IH: Recognizing the 75th Anniversa...
# ...                                                 ...
# 8009  115 SRES 79 ATS: Designating March 2, 2017, as...
# 8010  115 SRES 7 ATS: To constitute the majority par...
# 8011  115 SRES 80 ATS: Designating March 3, 2017, as...
# 8012  115 SRES 81 ATS: Recognizing the 196th anniver...
# 8013  115 SRES 81 IS: Recognizing the 196th annivers...
# 8014  115 SRES 82 ATS: Congratulating the Johns Hopk...
# 8015  115 SRES 83 ATS: Expressing the sense of the S...
# 8016  115 SRES 83 IS: Expressing the sense of the Se...
# 8017  115 SRES 84 ATS: Supporting the goals of Inter...
# 8018  115 SRES 85 IS: Calling on the Government of I...
# 8019  115 SRES 86 ATS: Recognizing the contributions...
# 8020  115 SRES 87 IS: Expressing the sense of the Se...
# 8021  115 SRES 88 IS: Expressing the sense of the Se...
# 8022  115 SRES 89 ATS: Supporting the designation of...
# 8023  115 SRES 8 ATS: To constitute the minority par...
# 8024  115 SRES 90 IS: Recognizing the importance of ...
# 8025  115 SRES 91 IS: Supporting the goals and ideal...
# 8026  115 SRES 92 IS: Expressing concern over the di...
# 8027  115 SRES 93 IS: Congratulating the European Un...
# 8028  115 SRES 94 ATS: Designating March 2017 as “Na...
# 8029  115 SRES 94 IS: Designating March 2017 as “Nat...
# 8030  115 SRES 95 ATS: Designating March 22, 2017, a...
# 8031  115 SRES 95 IS: Designating March 22, 2017, as...
# 8032  115 SRES 96 ATS: Designating March 25, 2017, a...
# 8033  115 SRES 97 ATS: Authorizing the printing of a...
# 8034  115 SRES 98 ATS: Designating the first week of...
# 8035  115 SRES 98 IS: Designating the first week of ...
# 8036  115 SRES 99 IS: Recognizing the 11 African-Ame...
# 8037  115 SRES 9 ATS: Honoring in praise and remembr...
# 8038  115 SRES 9 IS: Honoring in praise and remembra...
#
#                                file-name        legis-num  \
# 0        92510.140382952224512.47152.xml           S. 556
# 1      US_Bill_Text_115_HCONRES10_IH.xml  H. CON. RES. 10
# 2      US_Bill_Text_115_HCONRES11_IH.xml  H. CON. RES. 11
# 3      US_Bill_Text_115_HCONRES12_IH.xml  H. CON. RES. 12
# 4      US_Bill_Text_115_HCONRES13_IH.xml  H. CON. RES. 13
# 5      US_Bill_Text_115_HCONRES14_IH.xml  H. CON. RES. 14
# 6      US_Bill_Text_115_HCONRES15_IH.xml  H. CON. RES. 15
# 7      US_Bill_Text_115_HCONRES16_IH.xml  H. CON. RES. 16
# 8      US_Bill_Text_115_HCONRES17_IH.xml  H. CON. RES. 17
# 9      US_Bill_Text_115_HCONRES18_EH.xml  H. CON. RES. 18
# 10    US_Bill_Text_115_HCONRES18_ENR.xml  H. CON. RES. 18
# 11     US_Bill_Text_115_HCONRES18_IH.xml  H. CON. RES. 18
# 12    US_Bill_Text_115_HCONRES18_RDS.xml  H. CON. RES. 18
# 13     US_Bill_Text_115_HCONRES19_IH.xml  H. CON. RES. 19
# 14      US_Bill_Text_115_HCONRES1_EH.xml   H. CON. RES. 1
# 15     US_Bill_Text_115_HCONRES1_RDS.xml   H. CON. RES. 1
# 16     US_Bill_Text_115_HCONRES20_IH.xml  H. CON. RES. 20
# 17     US_Bill_Text_115_HCONRES21_IH.xml  H. CON. RES. 21
# 18     US_Bill_Text_115_HCONRES22_IH.xml  H. CON. RES. 22
# 19     US_Bill_Text_115_HCONRES23_EH.xml  H. CON. RES. 23
# 20    US_Bill_Text_115_HCONRES23_ENR.xml  H. CON. RES. 23
# 21    US_Bill_Text_115_HCONRES23_RDS.xml  H. CON. RES. 23
# 22     US_Bill_Text_115_HCONRES24_IH.xml  H. CON. RES. 24
# 23     US_Bill_Text_115_HCONRES25_IH.xml  H. CON. RES. 25
# 24     US_Bill_Text_115_HCONRES26_IH.xml  H. CON. RES. 26
# 25     US_Bill_Text_115_HCONRES27_IH.xml  H. CON. RES. 27
# 26     US_Bill_Text_115_HCONRES28_IH.xml  H. CON. RES. 28
# 27     US_Bill_Text_115_HCONRES29_IH.xml  H. CON. RES. 29
# 28      US_Bill_Text_115_HCONRES2_IH.xml   H. CON. RES. 2
# 29     US_Bill_Text_115_HCONRES30_IH.xml  H. CON. RES. 30
# ...                                  ...              ...
# 8009     US_Bill_Text_115_SRES79_ATS.xml       S. RES. 79
# 8010      US_Bill_Text_115_SRES7_ATS.xml        S. RES. 7
# 8011     US_Bill_Text_115_SRES80_ATS.xml       S. RES. 80
# 8012     US_Bill_Text_115_SRES81_ATS.xml       S. RES. 81
# 8013      US_Bill_Text_115_SRES81_IS.xml       S. RES. 81
# 8014     US_Bill_Text_115_SRES82_ATS.xml       S. RES. 82
# 8015     US_Bill_Text_115_SRES83_ATS.xml       S. RES. 83
# 8016      US_Bill_Text_115_SRES83_IS.xml       S. RES. 83
# 8017     US_Bill_Text_115_SRES84_ATS.xml       S. RES. 84
# 8018      US_Bill_Text_115_SRES85_IS.xml       S. RES. 85
# 8019     US_Bill_Text_115_SRES86_ATS.xml       S. RES. 86
# 8020      US_Bill_Text_115_SRES87_IS.xml       S. RES. 87
# 8021      US_Bill_Text_115_SRES88_IS.xml       S. RES. 88
# 8022     US_Bill_Text_115_SRES89_ATS.xml       S. RES. 89
# 8023      US_Bill_Text_115_SRES8_ATS.xml        S. RES. 8
# 8024      US_Bill_Text_115_SRES90_IS.xml       S. RES. 90
# 8025      US_Bill_Text_115_SRES91_IS.xml       S. RES. 91
# 8026      US_Bill_Text_115_SRES92_IS.xml       S. RES. 92
# 8027      US_Bill_Text_115_SRES93_IS.xml       S. RES. 93
# 8028     US_Bill_Text_115_SRES94_ATS.xml       S. RES. 94
# 8029      US_Bill_Text_115_SRES94_IS.xml       S. RES. 94
# 8030     US_Bill_Text_115_SRES95_ATS.xml       S. RES. 95
# 8031      US_Bill_Text_115_SRES95_IS.xml       S. RES. 95
# 8032     US_Bill_Text_115_SRES96_ATS.xml       S. RES. 96
# 8033     US_Bill_Text_115_SRES97_ATS.xml       S. RES. 97
# 8034     US_Bill_Text_115_SRES98_ATS.xml       S. RES. 98
# 8035      US_Bill_Text_115_SRES98_IS.xml       S. RES. 98
# 8036      US_Bill_Text_115_SRES99_IS.xml       S. RES. 99
# 8037      US_Bill_Text_115_SRES9_ATS.xml        S. RES. 9
# 8038       US_Bill_Text_115_SRES9_IS.xml        S. RES. 9
#
#                  legis-type legis-type.#text     ...      \
# 0                    A BILL              NaN     ...
# 1     CONCURRENT RESOLUTION              NaN     ...
# 2     CONCURRENT RESOLUTION              NaN     ...
# 3     CONCURRENT RESOLUTION              NaN     ...
# 4     CONCURRENT RESOLUTION              NaN     ...
# 5     CONCURRENT RESOLUTION              NaN     ...
# 6     CONCURRENT RESOLUTION              NaN     ...
# 7     CONCURRENT RESOLUTION              NaN     ...
# 8     CONCURRENT RESOLUTION              NaN     ...
# 9     CONCURRENT RESOLUTION              NaN     ...
# 10    CONCURRENT RESOLUTION              NaN     ...
# 11    CONCURRENT RESOLUTION              NaN     ...
# 12    CONCURRENT RESOLUTION              NaN     ...
# 13    CONCURRENT RESOLUTION              NaN     ...
# 14    CONCURRENT RESOLUTION              NaN     ...
# 15    CONCURRENT RESOLUTION              NaN     ...
# 16    CONCURRENT RESOLUTION              NaN     ...
# 17    CONCURRENT RESOLUTION              NaN     ...
# 18    CONCURRENT RESOLUTION              NaN     ...
# 19    CONCURRENT RESOLUTION              NaN     ...
# 20    CONCURRENT RESOLUTION              NaN     ...
# 21    CONCURRENT RESOLUTION              NaN     ...
# 22    CONCURRENT RESOLUTION              NaN     ...
# 23    CONCURRENT RESOLUTION              NaN     ...
# 24    CONCURRENT RESOLUTION              NaN     ...
# 25    CONCURRENT RESOLUTION              NaN     ...
# 26    CONCURRENT RESOLUTION              NaN     ...
# 27    CONCURRENT RESOLUTION              NaN     ...
# 28    CONCURRENT RESOLUTION              NaN     ...
# 29    CONCURRENT RESOLUTION              NaN     ...
# ...                     ...              ...     ...
# 8009             RESOLUTION              NaN     ...
# 8010             RESOLUTION              NaN     ...
# 8011             RESOLUTION              NaN     ...
# 8012             RESOLUTION              NaN     ...
# 8013             RESOLUTION              NaN     ...
# 8014             RESOLUTION              NaN     ...
# 8015             RESOLUTION              NaN     ...
# 8016             RESOLUTION              NaN     ...
# 8017             RESOLUTION              NaN     ...
# 8018             RESOLUTION              NaN     ...
# 8019             RESOLUTION              NaN     ...
# 8020             RESOLUTION              NaN     ...
# 8021             RESOLUTION              NaN     ...
# 8022             RESOLUTION              NaN     ...
# 8023             RESOLUTION              NaN     ...
# 8024             RESOLUTION              NaN     ...
# 8025             RESOLUTION              NaN     ...
# 8026             RESOLUTION              NaN     ...
# 8027             RESOLUTION              NaN     ...
# 8028             RESOLUTION              NaN     ...
# 8029             RESOLUTION              NaN     ...
# 8030             RESOLUTION              NaN     ...
# 8031             RESOLUTION              NaN     ...
# 8032             RESOLUTION              NaN     ...
# 8033             RESOLUTION              NaN     ...
# 8034             RESOLUTION              NaN     ...
# 8035             RESOLUTION              NaN     ...
# 8036             RESOLUTION              NaN     ...
# 8037             RESOLUTION              NaN     ...
# 8038             RESOLUTION              NaN     ...
#
#      metadata.@resolution-stage metadata.@resolution-type  \
# 0                           NaN                       NaN
# 1           Introduced-in-House          house-concurrent
# 2           Introduced-in-House          house-concurrent
# 3           Introduced-in-House          house-concurrent
# 4           Introduced-in-House          house-concurrent
# 5           Introduced-in-House          house-concurrent
# 6           Introduced-in-House          house-concurrent
# 7           Introduced-in-House          house-concurrent
# 8           Introduced-in-House          house-concurrent
# 9            Engrossed-in-House          house-concurrent
# 10                Enrolled-Bill          house-concurrent
# 11          Introduced-in-House          house-concurrent
# 12           Received-in-Senate          house-concurrent
# 13          Introduced-in-House          house-concurrent
# 14           Engrossed-in-House          house-concurrent
# 15           Received-in-Senate          house-concurrent
# 16          Introduced-in-House          house-concurrent
# 17          Introduced-in-House          house-concurrent
# 18          Introduced-in-House          house-concurrent
# 19           Engrossed-in-House          house-concurrent
# 20                Enrolled-Bill          house-concurrent
# 21           Received-in-Senate          house-concurrent
# 22          Introduced-in-House          house-concurrent
# 23          Introduced-in-House          house-concurrent
# 24          Introduced-in-House          house-concurrent
# 25          Introduced-in-House          house-concurrent
# 26          Introduced-in-House          house-concurrent
# 27          Introduced-in-House          house-concurrent
# 28          Introduced-in-House          house-concurrent
# 29          Introduced-in-House          house-concurrent
# ...                         ...                       ...
# 8009           Agreed-to-Senate         senate-resolution
# 8010           Agreed-to-Senate         senate-resolution
# 8011           Agreed-to-Senate         senate-resolution
# 8012           Agreed-to-Senate         senate-resolution
# 8013       Introduced-in-Senate         senate-resolution
# 8014           Agreed-to-Senate         senate-resolution
# 8015           Agreed-to-Senate         senate-resolution
# 8016       Introduced-in-Senate         senate-resolution
# 8017           Agreed-to-Senate         senate-resolution
# 8018       Introduced-in-Senate         senate-resolution
# 8019           Agreed-to-Senate         senate-resolution
# 8020       Introduced-in-Senate         senate-resolution
# 8021       Introduced-in-Senate         senate-resolution
# 8022           Agreed-to-Senate         senate-resolution
# 8023           Agreed-to-Senate         senate-resolution
# 8024       Introduced-in-Senate         senate-resolution
# 8025       Introduced-in-Senate         senate-resolution
# 8026       Introduced-in-Senate         senate-resolution
# 8027       Introduced-in-Senate         senate-resolution
# 8028           Agreed-to-Senate         senate-resolution
# 8029       Introduced-in-Senate         senate-resolution
# 8030           Agreed-to-Senate         senate-resolution
# 8031       Introduced-in-Senate         senate-resolution
# 8032           Agreed-to-Senate         senate-resolution
# 8033           Agreed-to-Senate         senate-resolution
# 8034           Agreed-to-Senate         senate-resolution
# 8035       Introduced-in-Senate         senate-resolution
# 8036       Introduced-in-Senate         senate-resolution
# 8037           Agreed-to-Senate         senate-resolution
# 8038       Introduced-in-Senate         senate-resolution
#
#      metadata.@stage-count metadata.@star-print  \
# 0                      NaN                  NaN
# 1                      NaN        no-star-print
# 2                      NaN        no-star-print
# 3                      NaN        no-star-print
# 4                      NaN        no-star-print
# 5                      NaN        no-star-print
# 6                      NaN        no-star-print
# 7                      NaN        no-star-print
# 8                      NaN        no-star-print
# 9                        1        no-star-print
# 10                       1        no-star-print
# 11                     NaN        no-star-print
# 12                       1        no-star-print
# 13                     NaN        no-star-print
# 14                       1        no-star-print
# 15                       1        no-star-print
# 16                     NaN        no-star-print
# 17                     NaN        no-star-print
# 18                     NaN        no-star-print
# 19                       1        no-star-print
# 20                       1        no-star-print
# 21                       1        no-star-print
# 22                     NaN        no-star-print
# 23                     NaN        no-star-print
# 24                     NaN        no-star-print
# 25                     NaN        no-star-print
# 26                     NaN        no-star-print
# 27                     NaN        no-star-print
# 28                     NaN        no-star-print
# 29                     NaN        no-star-print
# ...                    ...                  ...
# 8009                   NaN        no-star-print
# 8010                   NaN        no-star-print
# 8011                   NaN        no-star-print
# 8012                   NaN        no-star-print
# 8013                   NaN        no-star-print
# 8014                   NaN        no-star-print
# 8015                   NaN        no-star-print
# 8016                   NaN        no-star-print
# 8017                   NaN        no-star-print
# 8018                   NaN        no-star-print
# 8019                   NaN        no-star-print
# 8020                   NaN        no-star-print
# 8021                   NaN        no-star-print
# 8022                   NaN        no-star-print
# 8023                   NaN        no-star-print
# 8024                   NaN        no-star-print
# 8025                   NaN        no-star-print
# 8026                   NaN        no-star-print
# 8027                   NaN        no-star-print
# 8028                   NaN        no-star-print
# 8029                   NaN        no-star-print
# 8030                   NaN        no-star-print
# 8031                   NaN        no-star-print
# 8032                   NaN        no-star-print
# 8033                   NaN        no-star-print
# 8034                   NaN        no-star-print
# 8035                   NaN        no-star-print
# 8036                   NaN        no-star-print
# 8037                   NaN        no-star-print
# 8038                   NaN        no-star-print
#
#                                          official-title  \
# 0      For the relief of Joseph Gabra and Sharon Kamel.
# 1     Expressing the sense of the Congress that tax-...
# 2     Expressing the sense of Congress that Jerusale...
# 3     Supporting the designation of the week of Sept...
# 4               Supporting the Local Radio Freedom Act.
# 5     Establishing the Joint Ad Hoc Committee on Tra...
# 6     Asserting that Congress should expend the reso...
# 7     Expressing the sense of Congress that a commem...
# 8     Honoring and praising the National Association...
# 9     Permitting the use of the rotunda of the Capit...
# 10    Permitting the use of the rotunda of the Capit...
# 11    Permitting the use of the rotunda of the Capit...
# 12    Permitting the use of the rotunda of the Capit...
# 13    Expressing the sense of Congress regarding rec...
# 14    Regarding consent to assemble outside the seat...
# 15    Regarding consent to assemble outside the seat...
# 16    Expressing the sense of the House of Represent...
# 17    Reaffirming a strong commitment to the United ...
# 18    Recognizing the difficult challenges Black vet...
# 19    Providing for a joint session of Congress to r...
# 20    Providing for a joint session of Congress to r...
# 21    Providing for a joint session of Congress to r...
# 22    Establishing a Joint Committee on Russian Inte...
# 23    Expressing the sense of Congress on the admiss...
# 24    To express the sense of Congress that the firs...
# 25    Expressing the sense of Congress that America’...
# 26    Establishing a Joint Committee on the Organiza...
# 27    Expressing the sense of the Congress regarding...
# 28    To authorize the use of United States Armed Fo...
# 29    Recognizing the 75th Anniversary of the establ...
# ...                                                 ...
# 8009  Designating March 2, 2017, as "Read Across Ame...
# 8010  To constitute the majority party's  membership...
# 8011  Designating March 3, 2017, as "World Wildlife ...
# 8012  Recognizing the 196th anniversary of the indep...
# 8013  Recognizing the 196th anniversary of the indep...
# 8014  Congratulating the Johns Hopkins University Ap...
# 8015  Expressing the sense of the Senate regarding t...
# 8016  Expressing the sense of the Senate regarding t...
# 8017  Supporting the goals of International Women's ...
# 8018  Calling on the Government of Iran to fulfill r...
# 8019  Recognizing the contributions of AmeriCorps me...
# 8020  Expressing the sense of the Senate concerning ...
# 8021  Expressing the sense of the Senate that the Pr...
# 8022  Supporting the designation of March 2017 as "N...
# 8023  To constitute the minority party’s membership ...
# 8024  Recognizing the importance of the United State...
# 8025  Supporting the goals and ideals of  National P...
# 8026  Expressing concern over the disappearance of D...
# 8027  Congratulating the European Union on the 60th ...
# 8028  Designating March 2017 as "National Read Aloud...
# 8029  Designating March 2017 as "National Read Aloud...
# 8030  Designating March 22, 2017, as "National Rehab...
# 8031  Designating March 22, 2017, as "National Rehab...
# 8032  Designating March 25, 2017, as "National Cereb...
# 8033  Authorizing the printing of a collection of th...
# 8034  Designating the first week of April 2017 as "N...
# 8035  Designating the first week of April 2017 as "N...
# 8036  Recognizing the 11 African-American soldiers o...
# 8037  Honoring in praise and remembrance the extraor...
# 8038  Honoring in praise and remembrance the extraor...
#
#      official-title.@display section sentence  word    billInfo
# 0                        NaN       4       11   390       S 556
# 1                        NaN       5        1   126  HCONRES 10
# 2                        NaN       3        1    38  HCONRES 11
# 3                        NaN       4        1    80  HCONRES 12
# 4                        NaN       1        1    43  HCONRES 13
# 5                        NaN      20       39  1511  HCONRES 14
# 6                        NaN       3        1   228  HCONRES 15
# 7                        NaN       3        1    41  HCONRES 16
# 8                        NaN       3        4    84  HCONRES 17
# 9                        NaN       1        3    64  HCONRES 18
# 10                       NaN       1        3    64  HCONRES 18
# 11                       NaN       1        3    64  HCONRES 18
# 12                       NaN       1        3    64  HCONRES 18
# 13                       NaN       1        1    87  HCONRES 19
# 14                       NaN       1        1    83   HCONRES 1
# 15                       NaN       1        1    83   HCONRES 1
# 16                       NaN       6        1   196  HCONRES 20
# 17                       NaN       4        1    73  HCONRES 21
# 18                       NaN       3        1    68  HCONRES 22
# 19                       NaN       1        1    44  HCONRES 23
# 20                       NaN       1        1    44  HCONRES 23
# 21                       NaN       1        1    44  HCONRES 23
# 22                       NaN      30       32  1081  HCONRES 24
# 23                       NaN       6        2   150  HCONRES 25
# 24                       NaN       1        1    45  HCONRES 26
# 25                       NaN       1        1    29  HCONRES 27
# 26                       NaN      23       33  1029  HCONRES 28
# 27                       NaN       6        1   179  HCONRES 29
# 28                       NaN       5        9   252   HCONRES 2
# 29                       NaN       3        1    65  HCONRES 30
# ...                      ...     ...      ...   ...         ...
# 8009                     NaN       4        1    98     SRES 79
# 8010                     NaN       1       26   589      SRES 7
# 8011                     NaN       7        1   122     SRES 80
# 8012                     NaN       4        1    71     SRES 81
# 8013                     NaN       4        1    71     SRES 81
# 8014                     NaN       4        1    90     SRES 82
# 8015                     NaN       6        1   229     SRES 83
# 8016                     NaN       6        1   229     SRES 83
# 8017                     NaN       8        1   202     SRES 84
# 8018                     NaN       8        1   243     SRES 85
# 8019                     NaN       5        1    85     SRES 86
# 8020                     NaN      14        1   532     SRES 87
# 8021                     NaN       4        1    95     SRES 88
# 8022                     NaN       3        1    51     SRES 89
# 8023                     NaN       1       21   541      SRES 8
# 8024                     NaN       5        1   110     SRES 90
# 8025                     NaN       5        1   108     SRES 91
# 8026                     NaN       6        1   201     SRES 92
# 8027                     NaN       5        1   119     SRES 93
# 8028                     NaN       3        1    38     SRES 94
# 8029                     NaN       3        1    38     SRES 94
# 8030                     NaN       3        1    48     SRES 95
# 8031                     NaN       3        1    48     SRES 95
# 8032                     NaN       4        1    66     SRES 96
# 8033                     NaN       1        1    43     SRES 97
# 8034                     NaN       4        1    68     SRES 98
# 8035                     NaN       4        1    68     SRES 98
# 8036                     NaN       1        1    42     SRES 99
# 8037                     NaN       6        1   128      SRES 9
# 8038                     NaN       6        1   128      SRES 9
#
# [8039 rows x 30 columns]

# %%
summaries
# Out:
#      billNumber billType                                        contributor  \
# 0            24  HCONRES  Congressional Research Service, Library of Con...
# 1           165     HRES  Congressional Research Service, Library of Con...
# 2            12    SJRES  Congressional Research Service, Library of Con...
# 3           527        S  Congressional Research Service, Library of Con...
# 4           524        S  Congressional Research Service, Library of Con...
# 5           521        S  Congressional Research Service, Library of Con...
# 6           520        S  Congressional Research Service, Library of Con...
# 7           518        S  Congressional Research Service, Library of Con...
# 8           517        S  Congressional Research Service, Library of Con...
# 9           516        S  Congressional Research Service, Library of Con...
# 10          509        S  Congressional Research Service, Library of Con...
# 11          506        S  Congressional Research Service, Library of Con...
# 12          505        S  Congressional Research Service, Library of Con...
# 13          495        S  Congressional Research Service, Library of Con...
# 14          494        S  Congressional Research Service, Library of Con...
# 15          493        S  Congressional Research Service, Library of Con...
# 16          463        S  Congressional Research Service, Library of Con...
# 17          406        S  Congressional Research Service, Library of Con...
# 18          395        S  Congressional Research Service, Library of Con...
# 19          372        S  Congressional Research Service, Library of Con...
# 20          362        S  Congressional Research Service, Library of Con...
# 21          360        S  Congressional Research Service, Library of Con...
# 22          289        S  Congressional Research Service, Library of Con...
# 23          235        S  Congressional Research Service, Library of Con...
# 24          392        S  Congressional Research Service, Library of Con...
# 25          367        S  Congressional Research Service, Library of Con...
# 26          363        S  Congressional Research Service, Library of Con...
# 27           83     HRES  Congressional Research Service, Library of Con...
# 28           59     SRES  Congressional Research Service, Library of Con...
# 29          411        S  Congressional Research Service, Library of Con...
# ...         ...      ...                                                ...
# 8729         71     SRES  Congressional Research Service, Library of Con...
# 8730         72     SRES  Congressional Research Service, Library of Con...
# 8731         73     SRES  Congressional Research Service, Library of Con...
# 8732         74     SRES  Congressional Research Service, Library of Con...
# 8733         75     SRES  Congressional Research Service, Library of Con...
# 8734         76     SRES  Congressional Research Service, Library of Con...
# 8735         77     SRES  Congressional Research Service, Library of Con...
# 8736         79     SRES  Congressional Research Service, Library of Con...
# 8737          8     SRES  Congressional Research Service, Library of Con...
# 8738         80     SRES  Congressional Research Service, Library of Con...
# 8739         81     SRES  Congressional Research Service, Library of Con...
# 8740         82     SRES  Congressional Research Service, Library of Con...
# 8741         83     SRES  Congressional Research Service, Library of Con...
# 8742         84     SRES  Congressional Research Service, Library of Con...
# 8743         85     SRES  Congressional Research Service, Library of Con...
# 8744         86     SRES  Congressional Research Service, Library of Con...
# 8745         87     SRES  Congressional Research Service, Library of Con...
# 8746         88     SRES  Congressional Research Service, Library of Con...
# 8747         89     SRES  Congressional Research Service, Library of Con...
# 8748          9     SRES  Congressional Research Service, Library of Con...
# 8749         90     SRES  Congressional Research Service, Library of Con...
# 8750         91     SRES  Congressional Research Service, Library of Con...
# 8751         92     SRES  Congressional Research Service, Library of Con...
# 8752         93     SRES  Congressional Research Service, Library of Con...
# 8753         94     SRES  Congressional Research Service, Library of Con...
# 8754         95     SRES  Congressional Research Service, Library of Con...
# 8755         96     SRES  Congressional Research Service, Library of Con...
# 8756         97     SRES  Congressional Research Service, Library of Con...
# 8757         98     SRES  Congressional Research Service, Library of Con...
# 8758         99     SRES  Congressional Research Service, Library of Con...
#
#                              fileName  sentence0  sentence1  sentence2  \
# 0     104657.140052642395904.4245.xml        NaN        NaN        NaN
# 1     104657.140052642395904.4338.xml        NaN        NaN        NaN
# 2     104657.140052642395904.4450.xml        NaN        NaN        NaN
# 3     104657.140052642395904.4455.xml        NaN        NaN        NaN
# 4     104657.140052642395904.4458.xml        NaN        NaN        NaN
# 5     104657.140052642395904.4461.xml        NaN        NaN        NaN
# 6     104657.140052642395904.4462.xml        NaN        NaN        NaN
# 7     104657.140052642395904.4464.xml        NaN        NaN        NaN
# 8     104657.140052642395904.4465.xml        NaN        NaN        NaN
# 9     104657.140052642395904.4466.xml        NaN        NaN        NaN
# 10    104657.140052642395904.4473.xml        NaN        NaN        NaN
# 11    104657.140052642395904.4476.xml        NaN        NaN        NaN
# 12    104657.140052642395904.4477.xml        NaN        NaN        NaN
# 13    104657.140052642395904.4487.xml        NaN        NaN        NaN
# 14    104657.140052642395904.4488.xml        NaN        NaN        NaN
# 15    104657.140052642395904.4489.xml        NaN        NaN        NaN
# 16    104657.140052642395904.4499.xml        NaN        NaN        NaN
# 17    104657.140052642395904.4513.xml        NaN        NaN        NaN
# 18    104657.140052642395904.4515.xml        NaN        NaN        NaN
# 19    104657.140052642395904.4517.xml        NaN        NaN        NaN
# 20    104657.140052642395904.4518.xml        NaN        NaN        NaN
# 21    104657.140052642395904.4519.xml        NaN        NaN        NaN
# 22    104657.140052642395904.4527.xml        NaN        NaN        NaN
# 23    104657.140052642395904.4530.xml        NaN        NaN        NaN
# 24    104657.140052642395904.4911.xml        NaN        NaN        NaN
# 25    104657.140052642395904.4912.xml        1.0        NaN        NaN
# 26    104657.140052642395904.5351.xml        1.0        NaN        NaN
# 27    104657.140052642395904.5736.xml        1.0        NaN        NaN
# 28    104657.140052642395904.9638.xml        2.0        NaN        NaN
# 29    104657.140052642395904.9647.xml        NaN        NaN        NaN
# ...                               ...        ...        ...        ...
# 8729   US_Bill_Digest_115_sres_71.xml        1.0        NaN        NaN
# 8730   US_Bill_Digest_115_sres_72.xml        2.0        NaN        NaN
# 8731   US_Bill_Digest_115_sres_73.xml        2.0        4.0        NaN
# 8732   US_Bill_Digest_115_sres_74.xml        1.0        3.0        NaN
# 8733   US_Bill_Digest_115_sres_75.xml        2.0        NaN        NaN
# 8734   US_Bill_Digest_115_sres_76.xml        2.0        4.0        NaN
# 8735   US_Bill_Digest_115_sres_77.xml        3.0        5.0        NaN
# 8736   US_Bill_Digest_115_sres_79.xml        4.0        6.0        NaN
# 8737    US_Bill_Digest_115_sres_8.xml        1.0        3.0        NaN
# 8738   US_Bill_Digest_115_sres_80.xml        4.0        6.0        NaN
# 8739   US_Bill_Digest_115_sres_81.xml        3.0        5.0        NaN
# 8740   US_Bill_Digest_115_sres_82.xml        2.0        4.0        NaN
# 8741   US_Bill_Digest_115_sres_83.xml        2.0        4.0        NaN
# 8742   US_Bill_Digest_115_sres_84.xml        6.0        8.0        NaN
# 8743   US_Bill_Digest_115_sres_85.xml        6.0        NaN        NaN
# 8744   US_Bill_Digest_115_sres_86.xml        3.0        5.0        NaN
# 8745   US_Bill_Digest_115_sres_87.xml        5.0        NaN        NaN
# 8746   US_Bill_Digest_115_sres_88.xml        1.0        NaN        NaN
# 8747   US_Bill_Digest_115_sres_89.xml        1.0        3.0        NaN
# 8748    US_Bill_Digest_115_sres_9.xml        3.0        5.0        NaN
# 8749   US_Bill_Digest_115_sres_90.xml        4.0        NaN        NaN
# 8750   US_Bill_Digest_115_sres_91.xml        1.0        NaN        NaN
# 8751   US_Bill_Digest_115_sres_92.xml        4.0        NaN        NaN
# 8752   US_Bill_Digest_115_sres_93.xml        4.0        NaN        NaN
# 8753   US_Bill_Digest_115_sres_94.xml        2.0        4.0        NaN
# 8754   US_Bill_Digest_115_sres_95.xml        2.0        4.0        NaN
# 8755   US_Bill_Digest_115_sres_96.xml        1.0        3.0        NaN
# 8756   US_Bill_Digest_115_sres_97.xml        2.0        4.0        NaN
# 8757   US_Bill_Digest_115_sres_98.xml        2.0        4.0        NaN
# 8758   US_Bill_Digest_115_sres_99.xml        1.0        NaN        NaN
#
#       sentence3  sentence4                                           summary0  \
# 0           NaN        NaN                                                NaN
# 1           NaN        NaN                                                NaN
# 2           NaN        NaN                                                NaN
# 3           NaN        NaN                                                NaN
# 4           NaN        NaN                                                NaN
# 5           NaN        NaN                                                NaN
# 6           NaN        NaN                                                NaN
# 7           NaN        NaN                                                NaN
# 8           NaN        NaN                                                NaN
# 9           NaN        NaN                                                NaN
# 10          NaN        NaN                                                NaN
# 11          NaN        NaN                                                NaN
# 12          NaN        NaN                                                NaN
# 13          NaN        NaN                                                NaN
# 14          NaN        NaN                                                NaN
# 15          NaN        NaN                                                NaN
# 16          NaN        NaN                                                NaN
# 17          NaN        NaN                                                NaN
# 18          NaN        NaN                                                NaN
# 19          NaN        NaN                                                NaN
# 20          NaN        NaN                                                NaN
# 21          NaN        NaN                                                NaN
# 22          NaN        NaN                                                NaN
# 23          NaN        NaN                                                NaN
# 24          NaN        NaN                                                NaN
# 25          NaN        NaN  Probation Officer Protection Act of 2017 This ...
# 26          NaN        NaN  North Country National Scenic Trail Route Adju...
# 27          NaN        NaN  Provides amounts for expenses of the House Com...
# 28          NaN        NaN  Supports the designation of Darwin Day.  Recog...
# 29          NaN        NaN                                                NaN
# ...         ...        ...                                                ...
# 8729        NaN        NaN  Expresses the sense of the Senate that Jack Jo...
# 8730        NaN        NaN  Celebrates the history of the Detroit River wi...
# 8731        NaN        NaN  Designates February 28, 2017, as Rare Disease ...
# 8732        NaN        NaN  Congratulates Nebraska on the 150th anniversar...
# 8733        NaN        NaN   Commemorates October 20, 2017, as the 100th a...
# 8734        NaN        NaN  Supports the designation of March 21, 2017, as...
# 8735        NaN        NaN  Expresses support for the goals and ideals of ...
# 8736        NaN        NaN  Designates March 2, 2017, as Read Across Ameri...
# 8737        NaN        NaN  Designates the minority party membership on sp...
# 8738        NaN        NaN  Designates March 3, 2017, as World Wildlife Da...
# 8739        NaN        NaN  Congratulates the people of Greece as they cel...
# 8740        NaN        NaN  Congratulates the Johns Hopkins University App...
# 8741        NaN        NaN  Expresses the sense of the Senate that:   the ...
# 8742        NaN        NaN  Supports the goals of International Women's Da...
# 8743        NaN        NaN  Recognizes that March 9, 2017, marks 10 years ...
# 8744        NaN        NaN  Encourages the people of the United States to ...
# 8745        NaN        NaN  Condemns: (1) the regime of Bashar al-Assad fo...
# 8746        NaN        NaN  Expresses the sense of the Senate that: (1) th...
# 8747        NaN        NaN  Expresses support for the designation of March...
# 8748        NaN        NaN  Honors the life, leadership, and 70-year reign...
# 8749        NaN        NaN  Affirms that the U.S.-Israel economic partners...
# 8750        NaN        NaN  Supports the goals and ideals of National Prof...
# 8751        NaN        NaN  Expresses concern about the disappearance of D...
# 8752        NaN        NaN  Congratulates the European Union on the 60th a...
# 8753        NaN        NaN  Designates March 2017 as National Read Aloud M...
# 8754        NaN        NaN  Designates March 22, 2017, as National Rehabil...
# 8755        NaN        NaN  Designates March 25, 2017, as National Cerebra...
# 8756        NaN        NaN  Requires that a collection of the rules of the...
# 8757        NaN        NaN  Designates the first week of April 2017 as Nat...
# 8758        NaN        NaN  Recognizes the dedicated service and ultimate ...
#
#       ...  title72 title73 title74 title8 title9  word0  word1 word2 word3  \
# 0     ...      NaN     NaN     NaN    NaN    NaN    NaN    NaN   NaN   NaN
# 1     ...      NaN     NaN     NaN    NaN    NaN    NaN    NaN   NaN   NaN
# 2     ...      NaN     NaN     NaN    NaN    NaN    NaN    NaN   NaN   NaN
# 3     ...      NaN     NaN     NaN    NaN    NaN    NaN    NaN   NaN   NaN
# 4     ...      NaN     NaN     NaN    NaN    NaN    NaN    NaN   NaN   NaN
# 5     ...      NaN     NaN     NaN    NaN    NaN    NaN    NaN   NaN   NaN
# 6     ...      NaN     NaN     NaN    NaN    NaN    NaN    NaN   NaN   NaN
# 7     ...      NaN     NaN     NaN    NaN    NaN    NaN    NaN   NaN   NaN
# 8     ...      NaN     NaN     NaN    NaN    NaN    NaN    NaN   NaN   NaN
# 9     ...      NaN     NaN     NaN    NaN    NaN    NaN    NaN   NaN   NaN
# 10    ...      NaN     NaN     NaN    NaN    NaN    NaN    NaN   NaN   NaN
# 11    ...      NaN     NaN     NaN    NaN    NaN    NaN    NaN   NaN   NaN
# 12    ...      NaN     NaN     NaN    NaN    NaN    NaN    NaN   NaN   NaN
# 13    ...      NaN     NaN     NaN    NaN    NaN    NaN    NaN   NaN   NaN
# 14    ...      NaN     NaN     NaN    NaN    NaN    NaN    NaN   NaN   NaN
# 15    ...      NaN     NaN     NaN    NaN    NaN    NaN    NaN   NaN   NaN
# 16    ...      NaN     NaN     NaN    NaN    NaN    NaN    NaN   NaN   NaN
# 17    ...      NaN     NaN     NaN    NaN    NaN    NaN    NaN   NaN   NaN
# 18    ...      NaN     NaN     NaN    NaN    NaN    NaN    NaN   NaN   NaN
# 19    ...      NaN     NaN     NaN    NaN    NaN    NaN    NaN   NaN   NaN
# 20    ...      NaN     NaN     NaN    NaN    NaN    NaN    NaN   NaN   NaN
# 21    ...      NaN     NaN     NaN    NaN    NaN    NaN    NaN   NaN   NaN
# 22    ...      NaN     NaN     NaN    NaN    NaN    NaN    NaN   NaN   NaN
# 23    ...      NaN     NaN     NaN    NaN    NaN    NaN    NaN   NaN   NaN
# 24    ...      NaN     NaN     NaN    NaN    NaN    NaN    NaN   NaN   NaN
# 25    ...      NaN     NaN     NaN    NaN    NaN   55.0    NaN   NaN   NaN
# 26    ...      NaN     NaN     NaN    NaN    NaN   45.0    NaN   NaN   NaN
# 27    ...      NaN     NaN     NaN    NaN    NaN   14.0    NaN   NaN   NaN
# 28    ...      NaN     NaN     NaN    NaN    NaN   28.0    NaN   NaN   NaN
# 29    ...      NaN     NaN     NaN    NaN    NaN    NaN    NaN   NaN   NaN
# ...   ...      ...     ...     ...    ...    ...    ...    ...   ...   ...
# 8729  ...      NaN     NaN     NaN    NaN    NaN   59.0    NaN   NaN   NaN
# 8730  ...      NaN     NaN     NaN    NaN    NaN   71.0    NaN   NaN   NaN
# 8731  ...      NaN     NaN     NaN    NaN    NaN   28.0   46.0   NaN   NaN
# 8732  ...      NaN     NaN     NaN    NaN    NaN   13.0   31.0   NaN   NaN
# 8733  ...      NaN     NaN     NaN    NaN    NaN   39.0    NaN   NaN   NaN
# 8734  ...      NaN     NaN     NaN    NaN    NaN   24.0   42.0   NaN   NaN
# 8735  ...      NaN     NaN     NaN    NaN    NaN   76.0   94.0   NaN   NaN
# 8736  ...      NaN     NaN     NaN    NaN    NaN   52.0   70.0   NaN   NaN
# 8737  ...      NaN     NaN     NaN    NaN    NaN   13.0   31.0   NaN   NaN
# 8738  ...      NaN     NaN     NaN    NaN    NaN   92.0  110.0   NaN   NaN
# 8739  ...      NaN     NaN     NaN    NaN    NaN   53.0   71.0   NaN   NaN
# 8740  ...      NaN     NaN     NaN    NaN    NaN   57.0   75.0   NaN   NaN
# 8741  ...      NaN     NaN     NaN    NaN    NaN  163.0  181.0   NaN   NaN
# 8742  ...      NaN     NaN     NaN    NaN    NaN  148.0  166.0   NaN   NaN
# 8743  ...      NaN     NaN     NaN    NaN    NaN  156.0    NaN   NaN   NaN
# 8744  ...      NaN     NaN     NaN    NaN    NaN   72.0   90.0   NaN   NaN
# 8745  ...      NaN     NaN     NaN    NaN    NaN  316.0    NaN   NaN   NaN
# 8746  ...      NaN     NaN     NaN    NaN    NaN   86.0    NaN   NaN   NaN
# 8747  ...      NaN     NaN     NaN    NaN    NaN   14.0   32.0   NaN   NaN
# 8748  ...      NaN     NaN     NaN    NaN    NaN   62.0   80.0   NaN   NaN
# 8749  ...      NaN     NaN     NaN    NaN    NaN   89.0    NaN   NaN   NaN
# 8750  ...      NaN     NaN     NaN    NaN    NaN   23.0    NaN   NaN   NaN
# 8751  ...      NaN     NaN     NaN    NaN    NaN  126.0    NaN   NaN   NaN
# 8752  ...      NaN     NaN     NaN    NaN    NaN   74.0    NaN   NaN   NaN
# 8753  ...      NaN     NaN     NaN    NaN    NaN   32.0   50.0   NaN   NaN
# 8754  ...      NaN     NaN     NaN    NaN    NaN   21.0   39.0   NaN   NaN
# 8755  ...      NaN     NaN     NaN    NaN    NaN   10.0   28.0   NaN   NaN
# 8756  ...      NaN     NaN     NaN    NaN    NaN   34.0   52.0   NaN   NaN
# 8757  ...      NaN     NaN     NaN    NaN    NaN   31.0   49.0   NaN   NaN
# 8758  ...      NaN     NaN     NaN    NaN    NaN   45.0    NaN   NaN   NaN
#
#      word4
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# 8      NaN
# 9      NaN
# 10     NaN
# 11     NaN
# 12     NaN
# 13     NaN
# 14     NaN
# 15     NaN
# 16     NaN
# 17     NaN
# 18     NaN
# 19     NaN
# 20     NaN
# 21     NaN
# 22     NaN
# 23     NaN
# 24     NaN
# 25     NaN
# 26     NaN
# 27     NaN
# 28     NaN
# 29     NaN
# ...    ...
# 8729   NaN
# 8730   NaN
# 8731   NaN
# 8732   NaN
# 8733   NaN
# 8734   NaN
# 8735   NaN
# 8736   NaN
# 8737   NaN
# 8738   NaN
# 8739   NaN
# 8740   NaN
# 8741   NaN
# 8742   NaN
# 8743   NaN
# 8744   NaN
# 8745   NaN
# 8746   NaN
# 8747   NaN
# 8748   NaN
# 8749   NaN
# 8750   NaN
# 8751   NaN
# 8752   NaN
# 8753   NaN
# 8754   NaN
# 8755   NaN
# 8756   NaN
# 8757   NaN
# 8758   NaN
#
# [8759 rows x 95 columns]

# %%
with_summary = summaries[~summaries.summary0.isnull()]

# %%
with_summary
# Out:
#      billNumber billType                                        contributor  \
# 25          367        S  Congressional Research Service, Library of Con...
# 26          363        S  Congressional Research Service, Library of Con...
# 27           83     HRES  Congressional Research Service, Library of Con...
# 28           59     SRES  Congressional Research Service, Library of Con...
# 30          387        S  Congressional Research Service, Library of Con...
# 31          386        S  Congressional Research Service, Library of Con...
# 32          353        S  Congressional Research Service, Library of Con...
# 33          306        S  Congressional Research Service, Library of Con...
# 34          299        S  Congressional Research Service, Library of Con...
# 35          200        S  Congressional Research Service, Library of Con...
# 36          173        S  Congressional Research Service, Library of Con...
# 37          160        S  Congressional Research Service, Library of Con...
# 38           90        S  Congressional Research Service, Library of Con...
# 39           28     HRES  Congressional Research Service, Library of Con...
# 40          130     HRES  Congressional Research Service, Library of Con...
# 42           12     SRES  Congressional Research Service, Library of Con...
# 43           10    SJRES  Congressional Research Service, Library of Con...
# 55          185        S  Congressional Research Service, Library of Con...
# 57          343        S  Congressional Research Service, Library of Con...
# 58          328        S  Congressional Research Service, Library of Con...
# 59          246        S  Congressional Research Service, Library of Con...
# 60           39     SRES  Congressional Research Service, Library of Con...
# 61           37     SRES  Congressional Research Service, Library of Con...
# 62            3  SCONRES  Congressional Research Service, Library of Con...
# 63          305        S  Congressional Research Service, Library of Con...
# 64           21     SRES  Congressional Research Service, Library of Con...
# 65           20     SRES  Congressional Research Service, Library of Con...
# 68          324        S  Congressional Research Service, Library of Con...
# 69          280        S  Congressional Research Service, Library of Con...
# 70          275        S  Congressional Research Service, Library of Con...
# ...         ...      ...                                                ...
# 8729         71     SRES  Congressional Research Service, Library of Con...
# 8730         72     SRES  Congressional Research Service, Library of Con...
# 8731         73     SRES  Congressional Research Service, Library of Con...
# 8732         74     SRES  Congressional Research Service, Library of Con...
# 8733         75     SRES  Congressional Research Service, Library of Con...
# 8734         76     SRES  Congressional Research Service, Library of Con...
# 8735         77     SRES  Congressional Research Service, Library of Con...
# 8736         79     SRES  Congressional Research Service, Library of Con...
# 8737          8     SRES  Congressional Research Service, Library of Con...
# 8738         80     SRES  Congressional Research Service, Library of Con...
# 8739         81     SRES  Congressional Research Service, Library of Con...
# 8740         82     SRES  Congressional Research Service, Library of Con...
# 8741         83     SRES  Congressional Research Service, Library of Con...
# 8742         84     SRES  Congressional Research Service, Library of Con...
# 8743         85     SRES  Congressional Research Service, Library of Con...
# 8744         86     SRES  Congressional Research Service, Library of Con...
# 8745         87     SRES  Congressional Research Service, Library of Con...
# 8746         88     SRES  Congressional Research Service, Library of Con...
# 8747         89     SRES  Congressional Research Service, Library of Con...
# 8748          9     SRES  Congressional Research Service, Library of Con...
# 8749         90     SRES  Congressional Research Service, Library of Con...
# 8750         91     SRES  Congressional Research Service, Library of Con...
# 8751         92     SRES  Congressional Research Service, Library of Con...
# 8752         93     SRES  Congressional Research Service, Library of Con...
# 8753         94     SRES  Congressional Research Service, Library of Con...
# 8754         95     SRES  Congressional Research Service, Library of Con...
# 8755         96     SRES  Congressional Research Service, Library of Con...
# 8756         97     SRES  Congressional Research Service, Library of Con...
# 8757         98     SRES  Congressional Research Service, Library of Con...
# 8758         99     SRES  Congressional Research Service, Library of Con...
#
#                              fileName  sentence0  sentence1  sentence2  \
# 25    104657.140052642395904.4912.xml        1.0        NaN        NaN
# 26    104657.140052642395904.5351.xml        1.0        NaN        NaN
# 27    104657.140052642395904.5736.xml        1.0        NaN        NaN
# 28    104657.140052642395904.9638.xml        2.0        NaN        NaN
# 30    104657.140052642395904.9654.xml        2.0        NaN        NaN
# 31    104657.140052642395904.9655.xml        5.0        NaN        NaN
# 32    104657.140052642395904.9662.xml        3.0        NaN        NaN
# 33    104657.140052642395904.9667.xml        3.0        NaN        NaN
# 34    104657.140052642395904.9668.xml       10.0        NaN        NaN
# 35    104657.140052642395904.9676.xml        2.0        NaN        NaN
# 36    104657.140052642395904.9677.xml        1.0        NaN        NaN
# 37    104657.140052642395904.9679.xml        8.0        NaN        NaN
# 38    104657.140053172938496.4239.xml        7.0        NaN        NaN
# 39    104657.140053172938496.4242.xml        2.0        NaN        NaN
# 40    104657.140053172938496.4244.xml        1.0        NaN        NaN
# 42    104657.140053172938496.4443.xml        2.0        NaN        NaN
# 43    104657.140053172938496.4451.xml        2.0        NaN        NaN
# 55    104657.140053172938496.4534.xml        8.0        NaN        NaN
# 57    104657.140053172938496.4913.xml        1.0        NaN        NaN
# 58    104657.140053172938496.5011.xml        5.0        NaN        NaN
# 59    104657.140053172938496.5353.xml        6.0        NaN        NaN
# 60    104657.140053172938496.5731.xml        1.0        3.0        NaN
# 61    104657.140053172938496.5732.xml        1.0        3.0        NaN
# 62    104657.140053172938496.9543.xml        9.0       47.0       49.0
# 63    104657.140053172938496.9545.xml        1.0        NaN        NaN
# 64    104657.140053172938496.9641.xml        1.0        NaN        NaN
# 65    104657.140053172938496.9642.xml        1.0        NaN        NaN
# 68    104657.140053172938496.9665.xml        4.0        NaN        NaN
# 69    104657.140053172938496.9670.xml        6.0        NaN        NaN
# 70    104657.140053172938496.9671.xml        1.0        NaN        NaN
# ...                               ...        ...        ...        ...
# 8729   US_Bill_Digest_115_sres_71.xml        1.0        NaN        NaN
# 8730   US_Bill_Digest_115_sres_72.xml        2.0        NaN        NaN
# 8731   US_Bill_Digest_115_sres_73.xml        2.0        4.0        NaN
# 8732   US_Bill_Digest_115_sres_74.xml        1.0        3.0        NaN
# 8733   US_Bill_Digest_115_sres_75.xml        2.0        NaN        NaN
# 8734   US_Bill_Digest_115_sres_76.xml        2.0        4.0        NaN
# 8735   US_Bill_Digest_115_sres_77.xml        3.0        5.0        NaN
# 8736   US_Bill_Digest_115_sres_79.xml        4.0        6.0        NaN
# 8737    US_Bill_Digest_115_sres_8.xml        1.0        3.0        NaN
# 8738   US_Bill_Digest_115_sres_80.xml        4.0        6.0        NaN
# 8739   US_Bill_Digest_115_sres_81.xml        3.0        5.0        NaN
# 8740   US_Bill_Digest_115_sres_82.xml        2.0        4.0        NaN
# 8741   US_Bill_Digest_115_sres_83.xml        2.0        4.0        NaN
# 8742   US_Bill_Digest_115_sres_84.xml        6.0        8.0        NaN
# 8743   US_Bill_Digest_115_sres_85.xml        6.0        NaN        NaN
# 8744   US_Bill_Digest_115_sres_86.xml        3.0        5.0        NaN
# 8745   US_Bill_Digest_115_sres_87.xml        5.0        NaN        NaN
# 8746   US_Bill_Digest_115_sres_88.xml        1.0        NaN        NaN
# 8747   US_Bill_Digest_115_sres_89.xml        1.0        3.0        NaN
# 8748    US_Bill_Digest_115_sres_9.xml        3.0        5.0        NaN
# 8749   US_Bill_Digest_115_sres_90.xml        4.0        NaN        NaN
# 8750   US_Bill_Digest_115_sres_91.xml        1.0        NaN        NaN
# 8751   US_Bill_Digest_115_sres_92.xml        4.0        NaN        NaN
# 8752   US_Bill_Digest_115_sres_93.xml        4.0        NaN        NaN
# 8753   US_Bill_Digest_115_sres_94.xml        2.0        4.0        NaN
# 8754   US_Bill_Digest_115_sres_95.xml        2.0        4.0        NaN
# 8755   US_Bill_Digest_115_sres_96.xml        1.0        3.0        NaN
# 8756   US_Bill_Digest_115_sres_97.xml        2.0        4.0        NaN
# 8757   US_Bill_Digest_115_sres_98.xml        2.0        4.0        NaN
# 8758   US_Bill_Digest_115_sres_99.xml        1.0        NaN        NaN
#
#       sentence3  sentence4                                           summary0  \
# 25          NaN        NaN  Probation Officer Protection Act of 2017 This ...
# 26          NaN        NaN  North Country National Scenic Trail Route Adju...
# 27          NaN        NaN  Provides amounts for expenses of the House Com...
# 28          NaN        NaN  Supports the designation of Darwin Day.  Recog...
# 30          NaN        NaN  Consumer Financial Protection Bureau Accountab...
# 31          NaN        NaN  Judgment Fund Transparency and Terrorism Finan...
# 32          NaN        NaN  Preserve Access to Medicare Rural Home Health ...
# 33          NaN        NaN  Biennial Budgeting and Appropriations Act  Thi...
# 34          NaN        NaN  Agency Accountability Act of 2017 This bill re...
# 35          NaN        NaN  Restricting First Use of Nuclear Weapons Act o...
# 36          NaN        NaN  This bill requires the United States Postal Se...
# 37          NaN        NaN  HUD Inspection Process and Enforcement Reform ...
# 38          NaN        NaN  Red River Gradient Boundary Survey Act This bi...
# 39          NaN        NaN  Expresses the sense of the House of Representa...
# 40          NaN        NaN   Expresses support for efforts to build on the...
# 42          NaN        NaN  Calls for the nullification of the final rule ...
# 43          NaN        NaN  This joint resolution nullifies the Stream Pro...
# 55          NaN        NaN  Head Start Improvement Act of 2017 This bill a...
# 57          NaN        NaN  Repealing Existing Substandard Provisions Enco...
# 58          NaN        NaN  Equal Justice Under Law Act of 2017 This bill ...
# 59          NaN        NaN  Campus Fire Safety Education Act of 2017  This...
# 60          NaN        NaN  Authorizes expenditures by the Senate Committe...
# 61          NaN        NaN  Authorizes expenditures by the Senate Committe...
# 62          NaN        NaN  Establishes the congressional budget for the f...
# 63          NaN        NaN  Vietnam War Veterans Recognition Act of 2017 T...
# 64          NaN        NaN  Authorizes expenditures by the Senate Committe...
# 65          NaN        NaN  Authorizes expenditures by the Senate Committe...
# 68          NaN        NaN  State Veterans Home Adult Day Health Care Impr...
# 69          NaN        NaN  Crags, Colorado Land Exchange Act This bill di...
# 70          NaN        NaN  Agricultural Export Expansion Act of 2017 This...
# ...         ...        ...                                                ...
# 8729        NaN        NaN  Expresses the sense of the Senate that Jack Jo...
# 8730        NaN        NaN  Celebrates the history of the Detroit River wi...
# 8731        NaN        NaN  Designates February 28, 2017, as Rare Disease ...
# 8732        NaN        NaN  Congratulates Nebraska on the 150th anniversar...
# 8733        NaN        NaN   Commemorates October 20, 2017, as the 100th a...
# 8734        NaN        NaN  Supports the designation of March 21, 2017, as...
# 8735        NaN        NaN  Expresses support for the goals and ideals of ...
# 8736        NaN        NaN  Designates March 2, 2017, as Read Across Ameri...
# 8737        NaN        NaN  Designates the minority party membership on sp...
# 8738        NaN        NaN  Designates March 3, 2017, as World Wildlife Da...
# 8739        NaN        NaN  Congratulates the people of Greece as they cel...
# 8740        NaN        NaN  Congratulates the Johns Hopkins University App...
# 8741        NaN        NaN  Expresses the sense of the Senate that:   the ...
# 8742        NaN        NaN  Supports the goals of International Women's Da...
# 8743        NaN        NaN  Recognizes that March 9, 2017, marks 10 years ...
# 8744        NaN        NaN  Encourages the people of the United States to ...
# 8745        NaN        NaN  Condemns: (1) the regime of Bashar al-Assad fo...
# 8746        NaN        NaN  Expresses the sense of the Senate that: (1) th...
# 8747        NaN        NaN  Expresses support for the designation of March...
# 8748        NaN        NaN  Honors the life, leadership, and 70-year reign...
# 8749        NaN        NaN  Affirms that the U.S.-Israel economic partners...
# 8750        NaN        NaN  Supports the goals and ideals of National Prof...
# 8751        NaN        NaN  Expresses concern about the disappearance of D...
# 8752        NaN        NaN  Congratulates the European Union on the 60th a...
# 8753        NaN        NaN  Designates March 2017 as National Read Aloud M...
# 8754        NaN        NaN  Designates March 22, 2017, as National Rehabil...
# 8755        NaN        NaN  Designates March 25, 2017, as National Cerebra...
# 8756        NaN        NaN  Requires that a collection of the rules of the...
# 8757        NaN        NaN  Designates the first week of April 2017 as Nat...
# 8758        NaN        NaN  Recognizes the dedicated service and ultimate ...
#
#       ...  title72 title73 title74 title8 title9  word0   word1   word2 word3  \
# 25    ...      NaN     NaN     NaN    NaN    NaN   55.0     NaN     NaN   NaN
# 26    ...      NaN     NaN     NaN    NaN    NaN   45.0     NaN     NaN   NaN
# 27    ...      NaN     NaN     NaN    NaN    NaN   14.0     NaN     NaN   NaN
# 28    ...      NaN     NaN     NaN    NaN    NaN   28.0     NaN     NaN   NaN
# 30    ...      NaN     NaN     NaN    NaN    NaN   61.0     NaN     NaN   NaN
# 31    ...      NaN     NaN     NaN    NaN    NaN  203.0     NaN     NaN   NaN
# 32    ...      NaN     NaN     NaN    NaN    NaN  124.0     NaN     NaN   NaN
# 33    ...      NaN     NaN     NaN    NaN    NaN   93.0     NaN     NaN   NaN
# 34    ...      NaN     NaN     NaN    NaN    NaN  246.0     NaN     NaN   NaN
# 35    ...      NaN     NaN     NaN    NaN    NaN   76.0     NaN     NaN   NaN
# 36    ...      NaN     NaN     NaN    NaN    NaN   30.0     NaN     NaN   NaN
# 37    ...      NaN     NaN     NaN    NaN    NaN  259.0     NaN     NaN   NaN
# 38    ...      NaN     NaN     NaN    NaN    NaN  245.0     NaN     NaN   NaN
# 39    ...      NaN     NaN     NaN    NaN    NaN   31.0     NaN     NaN   NaN
# 40    ...      NaN     NaN     NaN    NaN    NaN   26.0     NaN     NaN   NaN
# 42    ...      NaN     NaN     NaN    NaN    NaN   54.0     NaN     NaN   NaN
# 43    ...      NaN     NaN     NaN    NaN    NaN   40.0     NaN     NaN   NaN
# 55    ...      NaN     NaN     NaN    NaN    NaN  222.0     NaN     NaN   NaN
# 57    ...      NaN     NaN     NaN    NaN    NaN   49.0     NaN     NaN   NaN
# 58    ...      NaN     NaN     NaN    NaN    NaN  139.0     NaN     NaN   NaN
# 59    ...      NaN     NaN     NaN    NaN    NaN  276.0     NaN     NaN   NaN
# 60    ...      NaN     NaN     NaN    NaN    NaN   16.0    34.0     NaN   NaN
# 61    ...      NaN     NaN     NaN    NaN    NaN   13.0    31.0     NaN   NaN
# 62    ...      NaN     NaN     NaN    NaN    NaN  231.0  1075.0  1100.0   NaN
# 63    ...      NaN     NaN     NaN    NaN    NaN   28.0     NaN     NaN   NaN
# 64    ...      NaN     NaN     NaN    NaN    NaN   17.0     NaN     NaN   NaN
# 65    ...      NaN     NaN     NaN    NaN    NaN   15.0     NaN     NaN   NaN
# 68    ...      NaN     NaN     NaN    NaN    NaN  157.0     NaN     NaN   NaN
# 69    ...      NaN     NaN     NaN    NaN    NaN  230.0     NaN     NaN   NaN
# 70    ...      NaN     NaN     NaN    NaN    NaN   51.0     NaN     NaN   NaN
# ...   ...      ...     ...     ...    ...    ...    ...     ...     ...   ...
# 8729  ...      NaN     NaN     NaN    NaN    NaN   59.0     NaN     NaN   NaN
# 8730  ...      NaN     NaN     NaN    NaN    NaN   71.0     NaN     NaN   NaN
# 8731  ...      NaN     NaN     NaN    NaN    NaN   28.0    46.0     NaN   NaN
# 8732  ...      NaN     NaN     NaN    NaN    NaN   13.0    31.0     NaN   NaN
# 8733  ...      NaN     NaN     NaN    NaN    NaN   39.0     NaN     NaN   NaN
# 8734  ...      NaN     NaN     NaN    NaN    NaN   24.0    42.0     NaN   NaN
# 8735  ...      NaN     NaN     NaN    NaN    NaN   76.0    94.0     NaN   NaN
# 8736  ...      NaN     NaN     NaN    NaN    NaN   52.0    70.0     NaN   NaN
# 8737  ...      NaN     NaN     NaN    NaN    NaN   13.0    31.0     NaN   NaN
# 8738  ...      NaN     NaN     NaN    NaN    NaN   92.0   110.0     NaN   NaN
# 8739  ...      NaN     NaN     NaN    NaN    NaN   53.0    71.0     NaN   NaN
# 8740  ...      NaN     NaN     NaN    NaN    NaN   57.0    75.0     NaN   NaN
# 8741  ...      NaN     NaN     NaN    NaN    NaN  163.0   181.0     NaN   NaN
# 8742  ...      NaN     NaN     NaN    NaN    NaN  148.0   166.0     NaN   NaN
# 8743  ...      NaN     NaN     NaN    NaN    NaN  156.0     NaN     NaN   NaN
# 8744  ...      NaN     NaN     NaN    NaN    NaN   72.0    90.0     NaN   NaN
# 8745  ...      NaN     NaN     NaN    NaN    NaN  316.0     NaN     NaN   NaN
# 8746  ...      NaN     NaN     NaN    NaN    NaN   86.0     NaN     NaN   NaN
# 8747  ...      NaN     NaN     NaN    NaN    NaN   14.0    32.0     NaN   NaN
# 8748  ...      NaN     NaN     NaN    NaN    NaN   62.0    80.0     NaN   NaN
# 8749  ...      NaN     NaN     NaN    NaN    NaN   89.0     NaN     NaN   NaN
# 8750  ...      NaN     NaN     NaN    NaN    NaN   23.0     NaN     NaN   NaN
# 8751  ...      NaN     NaN     NaN    NaN    NaN  126.0     NaN     NaN   NaN
# 8752  ...      NaN     NaN     NaN    NaN    NaN   74.0     NaN     NaN   NaN
# 8753  ...      NaN     NaN     NaN    NaN    NaN   32.0    50.0     NaN   NaN
# 8754  ...      NaN     NaN     NaN    NaN    NaN   21.0    39.0     NaN   NaN
# 8755  ...      NaN     NaN     NaN    NaN    NaN   10.0    28.0     NaN   NaN
# 8756  ...      NaN     NaN     NaN    NaN    NaN   34.0    52.0     NaN   NaN
# 8757  ...      NaN     NaN     NaN    NaN    NaN   31.0    49.0     NaN   NaN
# 8758  ...      NaN     NaN     NaN    NaN    NaN   45.0     NaN     NaN   NaN
#
#      word4
# 25     NaN
# 26     NaN
# 27     NaN
# 28     NaN
# 30     NaN
# 31     NaN
# 32     NaN
# 33     NaN
# 34     NaN
# 35     NaN
# 36     NaN
# 37     NaN
# 38     NaN
# 39     NaN
# 40     NaN
# 42     NaN
# 43     NaN
# 55     NaN
# 57     NaN
# 58     NaN
# 59     NaN
# 60     NaN
# 61     NaN
# 62     NaN
# 63     NaN
# 64     NaN
# 65     NaN
# 68     NaN
# 69     NaN
# 70     NaN
# ...    ...
# 8729   NaN
# 8730   NaN
# 8731   NaN
# 8732   NaN
# 8733   NaN
# 8734   NaN
# 8735   NaN
# 8736   NaN
# 8737   NaN
# 8738   NaN
# 8739   NaN
# 8740   NaN
# 8741   NaN
# 8742   NaN
# 8743   NaN
# 8744   NaN
# 8745   NaN
# 8746   NaN
# 8747   NaN
# 8748   NaN
# 8749   NaN
# 8750   NaN
# 8751   NaN
# 8752   NaN
# 8753   NaN
# 8754   NaN
# 8755   NaN
# 8756   NaN
# 8757   NaN
# 8758   NaN
#
# [5395 rows x 95 columns]

# %%
bills_sel = ['file-name', 'bill-type', 'legis-type','billInfo', 'body.section', 'section', 'sentence', 'word']
summaries_sel = ['fileName', 'sentence0', 'sentence1','sentence2', 'sentence3', 'sentence4', 
                              'summary0', 'summary1','summary2', 'summary3', 'summary4',
                              'word0', 'word1', 'word2', 'word3', 'word4']

# %%
matched3 = []
for i in range(len(with_summary)):
    new_dict = {}
    summaryInfo = ' '.join([with_summary.iloc[i]['billType'], with_summary.iloc[i]['billNumber']])
    matchingBills = bills[bills['billInfo'] == summaryInfo]
    if len(matchingBills) > 0:
        for col in summaries_sel:
            new_dict[col] = with_summary.iloc[i][col]
        if len(matchingBills) == 1:
            for col in bills_sel:
                try:
                    new_dict[col] = matchingBills[col].values[0]
                except:
                    new_dict[col] = matchingBills[col]
        else:
            for col in bills_sel:
                try:
                    new_dict[col] = matchingBills.iloc[0][col].values[0]
                except:
                    new_dict[col] = matchingBills.iloc[0][col]
        matched3.append(new_dict)

# %%
matched3_df = pd.DataFrame(matched3)

# %%
matched3_df.to_pickle('data/matched3.pkl')
