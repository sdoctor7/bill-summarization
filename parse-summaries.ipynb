# %%
import xmltodict
import pandas as pd
import os
from bs4 import BeautifulSoup

# %%
def parse_summary(path, fileName):

    with open(path+fileName) as file:
        dict1 = xmltodict.parse(file.read()) # parse original XML to a dictionary
    
    if 'billStatus' in dict1.keys():
        
        dict2 = {} # initialize empty dictionary for this bill
        dict2['fileName'] = fileName # insert filename
        dict2['billNumber'] = dict1['billStatus']['bill']['billNumber'] # insert bill number
        dict2['contributor'] = dict1['billStatus']['dublinCore']['dc:contributor'] # insert contributor

        ### summaries (there may be multiple) ###
        summaries = dict1['billStatus']['bill']['summaries']['billSummaries']
        if summaries:
            if isinstance(summaries['item'], dict): # if there's only one summary
                # remove HTML tags from the summary and append it
                dict2['summary0'] = BeautifulSoup(summaries['item']['text'], 'lxml').text
                
            elif isinstance(summaries['item'], list): # if there are multiple summaries
                for i, item in enumerate(summaries['item']):
                    # remove HTML tags from each summary and append it
                    dict2['summary'+str(i)] = BeautifulSoup(item['text'], 'lxml').text
        
        ### titles (there may be multiple) ###
        dict2['title'] = dict1['billStatus']['bill']['title']
        titles = dict1['billStatus']['bill']['titles']['item'] # original title in 'title' tag
        for i, item in enumerate(titles): # all other titles
            dict3 = {}
            dict3[item['titleType']] = item['title']
            dict2['title'+str(i)] = str(dict3)

        return (1, dict2)
    
    else:
        return (0, fileName)

# %%
path = '../data/summaries/'
all_dicts = []
unused_filenames = []

for summ_file in os.listdir(path):
    parsed = parse_summary(path, summ_file)
    if parsed[0] == 1:
        all_dicts.append(parsed[1])
    else:
        unused_filenames.append(parsed[1])

# %%
df = pd.DataFrame(all_dicts)
df
# Out:
#      billNumber                                        contributor  \
# 0            24  Congressional Research Service, Library of Con...
# 1           165  Congressional Research Service, Library of Con...
# 2            12  Congressional Research Service, Library of Con...
# 3           527  Congressional Research Service, Library of Con...
# 4           524  Congressional Research Service, Library of Con...
# 5           521  Congressional Research Service, Library of Con...
# 6           520  Congressional Research Service, Library of Con...
# 7           518  Congressional Research Service, Library of Con...
# 8           517  Congressional Research Service, Library of Con...
# 9           516  Congressional Research Service, Library of Con...
# 10          509  Congressional Research Service, Library of Con...
# 11          506  Congressional Research Service, Library of Con...
# 12          505  Congressional Research Service, Library of Con...
# 13          495  Congressional Research Service, Library of Con...
# 14          494  Congressional Research Service, Library of Con...
# 15          493  Congressional Research Service, Library of Con...
# 16          463  Congressional Research Service, Library of Con...
# 17          406  Congressional Research Service, Library of Con...
# 18          395  Congressional Research Service, Library of Con...
# 19          372  Congressional Research Service, Library of Con...
# 20          362  Congressional Research Service, Library of Con...
# 21          360  Congressional Research Service, Library of Con...
# 22          289  Congressional Research Service, Library of Con...
# 23          235  Congressional Research Service, Library of Con...
# 24          392  Congressional Research Service, Library of Con...
# 25          367  Congressional Research Service, Library of Con...
# 26          363  Congressional Research Service, Library of Con...
# 27           83  Congressional Research Service, Library of Con...
# 28           59  Congressional Research Service, Library of Con...
# 29          411  Congressional Research Service, Library of Con...
# ...         ...                                                ...
# 8729         71  Congressional Research Service, Library of Con...
# 8730         72  Congressional Research Service, Library of Con...
# 8731         73  Congressional Research Service, Library of Con...
# 8732         74  Congressional Research Service, Library of Con...
# 8733         75  Congressional Research Service, Library of Con...
# 8734         76  Congressional Research Service, Library of Con...
# 8735         77  Congressional Research Service, Library of Con...
# 8736         79  Congressional Research Service, Library of Con...
# 8737          8  Congressional Research Service, Library of Con...
# 8738         80  Congressional Research Service, Library of Con...
# 8739         81  Congressional Research Service, Library of Con...
# 8740         82  Congressional Research Service, Library of Con...
# 8741         83  Congressional Research Service, Library of Con...
# 8742         84  Congressional Research Service, Library of Con...
# 8743         85  Congressional Research Service, Library of Con...
# 8744         86  Congressional Research Service, Library of Con...
# 8745         87  Congressional Research Service, Library of Con...
# 8746         88  Congressional Research Service, Library of Con...
# 8747         89  Congressional Research Service, Library of Con...
# 8748          9  Congressional Research Service, Library of Con...
# 8749         90  Congressional Research Service, Library of Con...
# 8750         91  Congressional Research Service, Library of Con...
# 8751         92  Congressional Research Service, Library of Con...
# 8752         93  Congressional Research Service, Library of Con...
# 8753         94  Congressional Research Service, Library of Con...
# 8754         95  Congressional Research Service, Library of Con...
# 8755         96  Congressional Research Service, Library of Con...
# 8756         97  Congressional Research Service, Library of Con...
# 8757         98  Congressional Research Service, Library of Con...
# 8758         99  Congressional Research Service, Library of Con...
#
#                              fileName  \
# 0     104657.140052642395904.4245.xml
# 1     104657.140052642395904.4338.xml
# 2     104657.140052642395904.4450.xml
# 3     104657.140052642395904.4455.xml
# 4     104657.140052642395904.4458.xml
# 5     104657.140052642395904.4461.xml
# 6     104657.140052642395904.4462.xml
# 7     104657.140052642395904.4464.xml
# 8     104657.140052642395904.4465.xml
# 9     104657.140052642395904.4466.xml
# 10    104657.140052642395904.4473.xml
# 11    104657.140052642395904.4476.xml
# 12    104657.140052642395904.4477.xml
# 13    104657.140052642395904.4487.xml
# 14    104657.140052642395904.4488.xml
# 15    104657.140052642395904.4489.xml
# 16    104657.140052642395904.4499.xml
# 17    104657.140052642395904.4513.xml
# 18    104657.140052642395904.4515.xml
# 19    104657.140052642395904.4517.xml
# 20    104657.140052642395904.4518.xml
# 21    104657.140052642395904.4519.xml
# 22    104657.140052642395904.4527.xml
# 23    104657.140052642395904.4530.xml
# 24    104657.140052642395904.4911.xml
# 25    104657.140052642395904.4912.xml
# 26    104657.140052642395904.5351.xml
# 27    104657.140052642395904.5736.xml
# 28    104657.140052642395904.9638.xml
# 29    104657.140052642395904.9647.xml
# ...                               ...
# 8729   US_Bill_Digest_115_sres_71.xml
# 8730   US_Bill_Digest_115_sres_72.xml
# 8731   US_Bill_Digest_115_sres_73.xml
# 8732   US_Bill_Digest_115_sres_74.xml
# 8733   US_Bill_Digest_115_sres_75.xml
# 8734   US_Bill_Digest_115_sres_76.xml
# 8735   US_Bill_Digest_115_sres_77.xml
# 8736   US_Bill_Digest_115_sres_79.xml
# 8737    US_Bill_Digest_115_sres_8.xml
# 8738   US_Bill_Digest_115_sres_80.xml
# 8739   US_Bill_Digest_115_sres_81.xml
# 8740   US_Bill_Digest_115_sres_82.xml
# 8741   US_Bill_Digest_115_sres_83.xml
# 8742   US_Bill_Digest_115_sres_84.xml
# 8743   US_Bill_Digest_115_sres_85.xml
# 8744   US_Bill_Digest_115_sres_86.xml
# 8745   US_Bill_Digest_115_sres_87.xml
# 8746   US_Bill_Digest_115_sres_88.xml
# 8747   US_Bill_Digest_115_sres_89.xml
# 8748    US_Bill_Digest_115_sres_9.xml
# 8749   US_Bill_Digest_115_sres_90.xml
# 8750   US_Bill_Digest_115_sres_91.xml
# 8751   US_Bill_Digest_115_sres_92.xml
# 8752   US_Bill_Digest_115_sres_93.xml
# 8753   US_Bill_Digest_115_sres_94.xml
# 8754   US_Bill_Digest_115_sres_95.xml
# 8755   US_Bill_Digest_115_sres_96.xml
# 8756   US_Bill_Digest_115_sres_97.xml
# 8757   US_Bill_Digest_115_sres_98.xml
# 8758   US_Bill_Digest_115_sres_99.xml
#
#                                                summary0  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25    Probation Officer Protection Act of 2017 This ...
# 26    North Country National Scenic Trail Route Adju...
# 27    Provides amounts for expenses of the House Com...
# 28    Supports the designation of Darwin Day.  Recog...
# 29                                                  NaN
# ...                                                 ...
# 8729  Expresses the sense of the Senate that Jack Jo...
# 8730  Celebrates the history of the Detroit River wi...
# 8731  Designates February 28, 2017, as Rare Disease ...
# 8732  Congratulates Nebraska on the 150th anniversar...
# 8733   Commemorates October 20, 2017, as the 100th a...
# 8734  Supports the designation of March 21, 2017, as...
# 8735  Expresses support for the goals and ideals of ...
# 8736  Designates March 2, 2017, as Read Across Ameri...
# 8737  Designates the minority party membership on sp...
# 8738  Designates March 3, 2017, as World Wildlife Da...
# 8739  Congratulates the people of Greece as they cel...
# 8740  Congratulates the Johns Hopkins University App...
# 8741  Expresses the sense of the Senate that:   the ...
# 8742  Supports the goals of International Women's Da...
# 8743  Recognizes that March 9, 2017, marks 10 years ...
# 8744  Encourages the people of the United States to ...
# 8745  Condemns: (1) the regime of Bashar al-Assad fo...
# 8746  Expresses the sense of the Senate that: (1) th...
# 8747  Expresses support for the designation of March...
# 8748  Honors the life, leadership, and 70-year reign...
# 8749  Affirms that the U.S.-Israel economic partners...
# 8750  Supports the goals and ideals of National Prof...
# 8751  Expresses concern about the disappearance of D...
# 8752  Congratulates the European Union on the 60th a...
# 8753  Designates March 2017 as National Read Aloud M...
# 8754  Designates March 22, 2017, as National Rehabil...
# 8755  Designates March 25, 2017, as National Cerebra...
# 8756  Requires that a collection of the rules of the...
# 8757  Designates the first week of April 2017 as Nat...
# 8758  Recognizes the dedicated service and ultimate ...
#
#                                                summary1 summary2 summary3  \
# 0                                                   NaN      NaN      NaN
# 1                                                   NaN      NaN      NaN
# 2                                                   NaN      NaN      NaN
# 3                                                   NaN      NaN      NaN
# 4                                                   NaN      NaN      NaN
# 5                                                   NaN      NaN      NaN
# 6                                                   NaN      NaN      NaN
# 7                                                   NaN      NaN      NaN
# 8                                                   NaN      NaN      NaN
# 9                                                   NaN      NaN      NaN
# 10                                                  NaN      NaN      NaN
# 11                                                  NaN      NaN      NaN
# 12                                                  NaN      NaN      NaN
# 13                                                  NaN      NaN      NaN
# 14                                                  NaN      NaN      NaN
# 15                                                  NaN      NaN      NaN
# 16                                                  NaN      NaN      NaN
# 17                                                  NaN      NaN      NaN
# 18                                                  NaN      NaN      NaN
# 19                                                  NaN      NaN      NaN
# 20                                                  NaN      NaN      NaN
# 21                                                  NaN      NaN      NaN
# 22                                                  NaN      NaN      NaN
# 23                                                  NaN      NaN      NaN
# 24                                                  NaN      NaN      NaN
# 25                                                  NaN      NaN      NaN
# 26                                                  NaN      NaN      NaN
# 27                                                  NaN      NaN      NaN
# 28                                                  NaN      NaN      NaN
# 29                                                  NaN      NaN      NaN
# ...                                                 ...      ...      ...
# 8729                                                NaN      NaN      NaN
# 8730                                                NaN      NaN      NaN
# 8731  (This measure has not been amended since it wa...      NaN      NaN
# 8732  (This measure has not been amended since it wa...      NaN      NaN
# 8733                                                NaN      NaN      NaN
# 8734  (This measure has not been amended since it wa...      NaN      NaN
# 8735  (This measure has not been amended since it wa...      NaN      NaN
# 8736  (This measure has not been amended since it wa...      NaN      NaN
# 8737  (This measure has not been amended since it wa...      NaN      NaN
# 8738  (This measure has not been amended since it wa...      NaN      NaN
# 8739  (This measure has not been amended since it wa...      NaN      NaN
# 8740  (This measure has not been amended since it wa...      NaN      NaN
# 8741  (This measure has not been amended since it wa...      NaN      NaN
# 8742  (This measure has not been amended since it wa...      NaN      NaN
# 8743                                                NaN      NaN      NaN
# 8744  (This measure has not been amended since it wa...      NaN      NaN
# 8745                                                NaN      NaN      NaN
# 8746                                                NaN      NaN      NaN
# 8747  (This measure has not been amended since it wa...      NaN      NaN
# 8748  (This measure has not been amended since it wa...      NaN      NaN
# 8749                                                NaN      NaN      NaN
# 8750                                                NaN      NaN      NaN
# 8751                                                NaN      NaN      NaN
# 8752                                                NaN      NaN      NaN
# 8753  (This measure has not been amended since it wa...      NaN      NaN
# 8754  (This measure has not been amended since it wa...      NaN      NaN
# 8755  (This measure has not been amended since it wa...      NaN      NaN
# 8756  (This measure has not been amended since it wa...      NaN      NaN
# 8757  (This measure has not been amended since it wa...      NaN      NaN
# 8758                                                NaN      NaN      NaN
#
#      summary4                                              title  \
# 0         NaN  Establishing a Joint Committee on Russian Inte...
# 1         NaN  Expressing the sense of the House of Represent...
# 2         NaN  A joint resolution disapproving the rule submi...
# 3         NaN  A bill to improve access to emergency medical ...
# 4         NaN  A bill to amend the Internal Revenue Code of 1...
# 5         NaN  A bill to make the National Parks and Federal ...
# 6         NaN  A bill to amend title XIX of the Social Securi...
# 7         NaN  A bill to amend the Federal Water Pollution Co...
# 8         NaN  A bill to amend the Clean Air Act with respect...
# 9         NaN  A bill to provide grants to assist States in d...
# 10        NaN  A bill to improve the control and management o...
# 11        NaN  A bill to require that the Federal Government ...
# 12        NaN  A bill to amend the Internal Revenue Code of 1...
# 13        NaN  A bill to provide incentives for investment in...
# 14        NaN  A bill to improve transparency regarding the a...
# 15        NaN  A bill to amend title 38, United States Code, ...
# 16        NaN             Cancer Care Payment Reform Act of 2017
# 17        NaN                          Stopping Mass Hacking Act
# 18        NaN                                            GPS Act
# 19        NaN                                   STOP Act of 2017
# 20        NaN  Federal Employees Paid Parental Leave Act of 2017
# 21        NaN                          Same Day Registration Act
# 22        NaN  Arapaho National Forest Boundary Adjustment Ac...
# 23        NaN                                         CHOICE Act
# 24        NaN  400 Years of African-American History Commissi...
# 25        NaN           Probation Officer Protection Act of 2017
# 26        NaN  North Country National Scenic Trail Route Adju...
# 27        NaN  Providing amounts for the expenses of the Comm...
# 28        NaN  A resolution expressing the support for the de...
# 29        NaN                                              ERRPA
# ...       ...                                                ...
# 8729      NaN  A resolution expressing the sense of the Senat...
# 8730      NaN  A resolution celebrating the history of the De...
# 8731      NaN  A resolution designating February 28, 2017, as...
# 8732      NaN  A resolution congratulating the State of Nebra...
# 8733      NaN  A resolution recognizing the 100th anniversary...
# 8734      NaN  A resolution expressing support for the design...
# 8735      NaN  A resolution supporting the goals and ideals o...
# 8736      NaN  A resolution designating March 2, 2017, as "Re...
# 8737      NaN  A resolution to constitute the minority party'...
# 8738      NaN  A resolution designating March 3, 2017, as "Wo...
# 8739      NaN  A resolution recognizing the 196th anniversary...
# 8740      NaN  A resolution congratulating the Johns Hopkins ...
# 8741      NaN  A resolution expressing the sense of the Senat...
# 8742      NaN  A resolution supporting the goals of Internati...
# 8743      NaN  A resolution calling on the Government of Iran...
# 8744      NaN  A resolution recognizing the contributions of ...
# 8745      NaN  A resolution expressing the sense of the Senat...
# 8746      NaN  A resolution expressing the sense of the Senat...
# 8747      NaN  A resolution supporting the designation of Mar...
# 8748      NaN  A resolution honoring in praise and remembranc...
# 8749      NaN  A resolution recognizing the importance of the...
# 8750      NaN  A resolution supporting the goals and ideals o...
# 8751      NaN  A resolution expressing concern over the disap...
# 8752      NaN  A resolution congratulating the European Union...
# 8753      NaN  A resolution designating March 2017 as "Nation...
# 8754      NaN  A resolution designating March 22, 2017, as "N...
# 8755      NaN  A resolution designating March 25, 2017, as "N...
# 8756      NaN  A resolution authorizing the printing of a col...
# 8757      NaN  A resolution designating the first week of Apr...
# 8758      NaN  A resolution recognizing the 11 African-Americ...
#
#                                                  title0  ...   title68  \
# 0     {'Official Title as Introduced': 'Establishing...  ...       NaN
# 1     {'Official Title as Introduced': 'Expressing t...  ...       NaN
# 2     {'Official Title as Introduced': 'A joint reso...  ...       NaN
# 3     {'Official Title as Introduced': 'A bill to im...  ...       NaN
# 4     {'Official Title as Introduced': 'A bill to am...  ...       NaN
# 5     {'Official Title as Introduced': 'A bill to ma...  ...       NaN
# 6     {'Official Title as Introduced': 'A bill to am...  ...       NaN
# 7     {'Official Title as Introduced': 'A bill to am...  ...       NaN
# 8     {'Official Title as Introduced': 'A bill to am...  ...       NaN
# 9     {'Official Title as Introduced': 'A bill to pr...  ...       NaN
# 10    {'Official Title as Introduced': 'A bill to im...  ...       NaN
# 11    {'Official Title as Introduced': 'A bill to re...  ...       NaN
# 12    {'Official Title as Introduced': 'A bill to am...  ...       NaN
# 13    {'Official Title as Introduced': 'A bill to pr...  ...       NaN
# 14    {'Official Title as Introduced': 'A bill to im...  ...       NaN
# 15    {'Official Title as Introduced': 'A bill to am...  ...       NaN
# 16    {'Short Titles as Introduced': 'Cancer Care Pa...  ...       NaN
# 17    {'Short Titles as Introduced': 'Stopping Mass ...  ...       NaN
# 18            {'Short Titles as Introduced': 'GPS Act'}  ...       NaN
# 19    {'Short Titles as Introduced': 'STOP Act of 20...  ...       NaN
# 20    {'Short Titles as Introduced': 'Federal Employ...  ...       NaN
# 21    {'Short Titles as Introduced': 'Same Day Regis...  ...       NaN
# 22    {'Short Titles as Introduced': 'Arapaho Nation...  ...       NaN
# 23         {'Short Titles as Introduced': 'CHOICE Act'}  ...       NaN
# 24    {'Short Titles as Introduced': '400 Years of A...  ...       NaN
# 25    {'Short Titles as Introduced': 'Probation Offi...  ...       NaN
# 26    {'Short Titles as Introduced': 'North Country ...  ...       NaN
# 27    {'Official Title as Introduced': 'Providing am...  ...       NaN
# 28    {'Official Title as Introduced': 'A resolution...  ...       NaN
# 29              {'Short Titles as Introduced': 'ERRPA'}  ...       NaN
# ...                                                 ...  ...       ...
# 8729  {'Official Title as Introduced': 'A resolution...  ...       NaN
# 8730  {'Official Title as Introduced': 'A resolution...  ...       NaN
# 8731  {'Official Title as Introduced': 'A resolution...  ...       NaN
# 8732  {'Official Title as Introduced': 'A resolution...  ...       NaN
# 8733  {'Official Title as Introduced': 'A resolution...  ...       NaN
# 8734  {'Official Title as Introduced': 'A resolution...  ...       NaN
# 8735  {'Official Title as Introduced': 'A resolution...  ...       NaN
# 8736  {'Official Title as Introduced': 'A resolution...  ...       NaN
# 8737  {'Official Title as Introduced': "A resolution...  ...       NaN
# 8738  {'Official Title as Introduced': 'A resolution...  ...       NaN
# 8739  {'Official Title as Introduced': 'A resolution...  ...       NaN
# 8740  {'Official Title as Introduced': 'A resolution...  ...       NaN
# 8741  {'Official Title as Introduced': 'A resolution...  ...       NaN
# 8742  {'Official Title as Introduced': "A resolution...  ...       NaN
# 8743  {'Official Title as Introduced': "A resolution...  ...       NaN
# 8744  {'Official Title as Introduced': 'A resolution...  ...       NaN
# 8745  {'Official Title as Introduced': 'A resolution...  ...       NaN
# 8746  {'Official Title as Introduced': 'A resolution...  ...       NaN
# 8747  {'Official Title as Introduced': 'A resolution...  ...       NaN
# 8748  {'Official Title as Introduced': 'A resolution...  ...       NaN
# 8749  {'Official Title as Introduced': 'A resolution...  ...       NaN
# 8750  {'Official Title as Introduced': 'A resolution...  ...       NaN
# 8751  {'Official Title as Introduced': 'A resolution...  ...       NaN
# 8752  {'Official Title as Introduced': 'A resolution...  ...       NaN
# 8753  {'Official Title as Introduced': 'A resolution...  ...       NaN
# 8754  {'Official Title as Introduced': 'A resolution...  ...       NaN
# 8755  {'Official Title as Introduced': 'A resolution...  ...       NaN
# 8756  {'Official Title as Introduced': 'A resolution...  ...       NaN
# 8757  {'Official Title as Introduced': 'A resolution...  ...       NaN
# 8758  {'Official Title as Introduced': 'A resolution...  ...       NaN
#
#      title69 title7 title70 title71 title72 title73 title74 title8 title9
# 0        NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 1        NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 2        NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 3        NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 4        NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 5        NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 6        NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 7        NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 8        NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 9        NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 10       NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 11       NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 12       NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 13       NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 14       NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 15       NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 16       NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 17       NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 18       NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 19       NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 20       NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 21       NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 22       NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 23       NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 24       NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 25       NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 26       NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 27       NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 28       NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 29       NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# ...      ...    ...     ...     ...     ...     ...     ...    ...    ...
# 8729     NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 8730     NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 8731     NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 8732     NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 8733     NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 8734     NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 8735     NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 8736     NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 8737     NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 8738     NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 8739     NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 8740     NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 8741     NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 8742     NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 8743     NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 8744     NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 8745     NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 8746     NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 8747     NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 8748     NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 8749     NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 8750     NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 8751     NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 8752     NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 8753     NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 8754     NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 8755     NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 8756     NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 8757     NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 8758     NaN    NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
#
# [8759 rows x 84 columns]

# %%
print('Number of files we received: ', len([name for name in os.listdir(path)]))
print('Number of bills with a valid file: ', len(df))
print('Number of bills with at least one summary: ', sum(df.summary0.notnull()))
# Out:
# Number of files we received:  8837
# Number of bills with a valid file:  8759
# Number of bills with at least one summary:  5395
