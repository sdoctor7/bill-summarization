# %%
import xmltodict
import pandas as pd
import os
from bs4 import BeautifulSoup
from utils import *

# %%
def parse_summary(path, fileName):

    with open(path+fileName, 'rb') as file:
        dict1 = xmltodict.parse(file.read()) # parse original XML to a dictionary
    
    if 'billStatus' in dict1.keys():
        
        dict2 = {} # initialize empty dictionary for this bill
        dict2['fileName'] = fileName # insert filename
        dict2['billNumber'] = dict1['billStatus']['bill']['billNumber'] # insert bill number
        dict2['contributor'] = dict1['billStatus']['dublinCore']['dc:contributor'] # insert contributor

        ### summaries (there may be multiple) ###
        summaries = dict1['billStatus']['bill']['summaries']['billSummaries']
        if summaries:
            if isinstance(summaries['item'], dict): # if there's only one summary
                # remove HTML tags from the summary and append it
                dict2['summary0'] = BeautifulSoup(summaries['item']['text'], 'lxml').text
                # add length fields (sentence and word) to columns
                dict2['sentence0'], dict2['word0'] = length_bill(dict2['summary0'])
            elif isinstance(summaries['item'], list): # if there are multiple summaries
                for i, item in enumerate(summaries['item']):
                    # remove HTML tags from each summary and append it
                    dict2['summary'+str(i)] = BeautifulSoup(item['text'], 'lxml').text
                    # add length fields (sentence and word) to columns
                    dict2['sentence'+str(i)], dict2['word'+str(i)] = length_bill(dict2['summary'+str(i)])
        
        ### titles (there may be multiple) ###
        dict2['title'] = dict1['billStatus']['bill']['title']
        titles = dict1['billStatus']['bill']['titles']['item'] # original title in 'title' tag
        for i, item in enumerate(titles): # all other titles
            dict3 = {}
            dict3[item['titleType']] = item['title']
            dict2['title'+str(i)] = str(dict3)

        return (1, dict2)
    
    else:
        return (0, fileName)

# %%
path = './data/summaries/'
all_dicts = []
unused_filenames = []
count = 0
for summ_file in os.listdir(path):
    parsed = parse_summary(path, summ_file)
    if count%1000==0:
        print (count)
    if parsed[0] == 1:
        all_dicts.append(parsed[1])
    else:
        unused_filenames.append(parsed[1])
    count+=1
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000

# %%
df = pd.DataFrame(all_dicts)
df.to_pickle("data/summaries.pkl")
df
# Out:
#      billNumber                                        contributor  \
# 0            24  Congressional Research Service, Library of Con...
# 1           165  Congressional Research Service, Library of Con...
# 2            12  Congressional Research Service, Library of Con...
# 3           527  Congressional Research Service, Library of Con...
# 4           524  Congressional Research Service, Library of Con...
# 5           521  Congressional Research Service, Library of Con...
# 6           520  Congressional Research Service, Library of Con...
# 7           518  Congressional Research Service, Library of Con...
# 8           517  Congressional Research Service, Library of Con...
# 9           516  Congressional Research Service, Library of Con...
# 10          509  Congressional Research Service, Library of Con...
# 11          506  Congressional Research Service, Library of Con...
# 12          505  Congressional Research Service, Library of Con...
# 13          495  Congressional Research Service, Library of Con...
# 14          494  Congressional Research Service, Library of Con...
# 15          493  Congressional Research Service, Library of Con...
# 16          463  Congressional Research Service, Library of Con...
# 17          406  Congressional Research Service, Library of Con...
# 18          395  Congressional Research Service, Library of Con...
# 19          372  Congressional Research Service, Library of Con...
# 20          362  Congressional Research Service, Library of Con...
# 21          360  Congressional Research Service, Library of Con...
# 22          289  Congressional Research Service, Library of Con...
# 23          235  Congressional Research Service, Library of Con...
# 24          392  Congressional Research Service, Library of Con...
# 25          367  Congressional Research Service, Library of Con...
# 26          363  Congressional Research Service, Library of Con...
# 27           83  Congressional Research Service, Library of Con...
# 28           59  Congressional Research Service, Library of Con...
# 29          411  Congressional Research Service, Library of Con...
# ...         ...                                                ...
# 8729         71  Congressional Research Service, Library of Con...
# 8730         72  Congressional Research Service, Library of Con...
# 8731         73  Congressional Research Service, Library of Con...
# 8732         74  Congressional Research Service, Library of Con...
# 8733         75  Congressional Research Service, Library of Con...
# 8734         76  Congressional Research Service, Library of Con...
# 8735         77  Congressional Research Service, Library of Con...
# 8736         79  Congressional Research Service, Library of Con...
# 8737          8  Congressional Research Service, Library of Con...
# 8738         80  Congressional Research Service, Library of Con...
# 8739         81  Congressional Research Service, Library of Con...
# 8740         82  Congressional Research Service, Library of Con...
# 8741         83  Congressional Research Service, Library of Con...
# 8742         84  Congressional Research Service, Library of Con...
# 8743         85  Congressional Research Service, Library of Con...
# 8744         86  Congressional Research Service, Library of Con...
# 8745         87  Congressional Research Service, Library of Con...
# 8746         88  Congressional Research Service, Library of Con...
# 8747         89  Congressional Research Service, Library of Con...
# 8748          9  Congressional Research Service, Library of Con...
# 8749         90  Congressional Research Service, Library of Con...
# 8750         91  Congressional Research Service, Library of Con...
# 8751         92  Congressional Research Service, Library of Con...
# 8752         93  Congressional Research Service, Library of Con...
# 8753         94  Congressional Research Service, Library of Con...
# 8754         95  Congressional Research Service, Library of Con...
# 8755         96  Congressional Research Service, Library of Con...
# 8756         97  Congressional Research Service, Library of Con...
# 8757         98  Congressional Research Service, Library of Con...
# 8758         99  Congressional Research Service, Library of Con...
#
#                              fileName  sentence0  sentence1  sentence2  \
# 0     104657.140052642395904.4245.xml        NaN        NaN        NaN
# 1     104657.140052642395904.4338.xml        NaN        NaN        NaN
# 2     104657.140052642395904.4450.xml        NaN        NaN        NaN
# 3     104657.140052642395904.4455.xml        NaN        NaN        NaN
# 4     104657.140052642395904.4458.xml        NaN        NaN        NaN
# 5     104657.140052642395904.4461.xml        NaN        NaN        NaN
# 6     104657.140052642395904.4462.xml        NaN        NaN        NaN
# 7     104657.140052642395904.4464.xml        NaN        NaN        NaN
# 8     104657.140052642395904.4465.xml        NaN        NaN        NaN
# 9     104657.140052642395904.4466.xml        NaN        NaN        NaN
# 10    104657.140052642395904.4473.xml        NaN        NaN        NaN
# 11    104657.140052642395904.4476.xml        NaN        NaN        NaN
# 12    104657.140052642395904.4477.xml        NaN        NaN        NaN
# 13    104657.140052642395904.4487.xml        NaN        NaN        NaN
# 14    104657.140052642395904.4488.xml        NaN        NaN        NaN
# 15    104657.140052642395904.4489.xml        NaN        NaN        NaN
# 16    104657.140052642395904.4499.xml        NaN        NaN        NaN
# 17    104657.140052642395904.4513.xml        NaN        NaN        NaN
# 18    104657.140052642395904.4515.xml        NaN        NaN        NaN
# 19    104657.140052642395904.4517.xml        NaN        NaN        NaN
# 20    104657.140052642395904.4518.xml        NaN        NaN        NaN
# 21    104657.140052642395904.4519.xml        NaN        NaN        NaN
# 22    104657.140052642395904.4527.xml        NaN        NaN        NaN
# 23    104657.140052642395904.4530.xml        NaN        NaN        NaN
# 24    104657.140052642395904.4911.xml        NaN        NaN        NaN
# 25    104657.140052642395904.4912.xml        1.0        NaN        NaN
# 26    104657.140052642395904.5351.xml        1.0        NaN        NaN
# 27    104657.140052642395904.5736.xml        1.0        NaN        NaN
# 28    104657.140052642395904.9638.xml        2.0        NaN        NaN
# 29    104657.140052642395904.9647.xml        NaN        NaN        NaN
# ...                               ...        ...        ...        ...
# 8729   US_Bill_Digest_115_sres_71.xml        1.0        NaN        NaN
# 8730   US_Bill_Digest_115_sres_72.xml        2.0        NaN        NaN
# 8731   US_Bill_Digest_115_sres_73.xml        2.0        4.0        NaN
# 8732   US_Bill_Digest_115_sres_74.xml        1.0        3.0        NaN
# 8733   US_Bill_Digest_115_sres_75.xml        2.0        NaN        NaN
# 8734   US_Bill_Digest_115_sres_76.xml        2.0        4.0        NaN
# 8735   US_Bill_Digest_115_sres_77.xml        3.0        5.0        NaN
# 8736   US_Bill_Digest_115_sres_79.xml        4.0        6.0        NaN
# 8737    US_Bill_Digest_115_sres_8.xml        1.0        3.0        NaN
# 8738   US_Bill_Digest_115_sres_80.xml        4.0        6.0        NaN
# 8739   US_Bill_Digest_115_sres_81.xml        3.0        5.0        NaN
# 8740   US_Bill_Digest_115_sres_82.xml        2.0        4.0        NaN
# 8741   US_Bill_Digest_115_sres_83.xml        2.0        4.0        NaN
# 8742   US_Bill_Digest_115_sres_84.xml        6.0        8.0        NaN
# 8743   US_Bill_Digest_115_sres_85.xml        6.0        NaN        NaN
# 8744   US_Bill_Digest_115_sres_86.xml        3.0        5.0        NaN
# 8745   US_Bill_Digest_115_sres_87.xml        5.0        NaN        NaN
# 8746   US_Bill_Digest_115_sres_88.xml        1.0        NaN        NaN
# 8747   US_Bill_Digest_115_sres_89.xml        1.0        3.0        NaN
# 8748    US_Bill_Digest_115_sres_9.xml        3.0        5.0        NaN
# 8749   US_Bill_Digest_115_sres_90.xml        4.0        NaN        NaN
# 8750   US_Bill_Digest_115_sres_91.xml        1.0        NaN        NaN
# 8751   US_Bill_Digest_115_sres_92.xml        4.0        NaN        NaN
# 8752   US_Bill_Digest_115_sres_93.xml        4.0        NaN        NaN
# 8753   US_Bill_Digest_115_sres_94.xml        2.0        4.0        NaN
# 8754   US_Bill_Digest_115_sres_95.xml        2.0        4.0        NaN
# 8755   US_Bill_Digest_115_sres_96.xml        1.0        3.0        NaN
# 8756   US_Bill_Digest_115_sres_97.xml        2.0        4.0        NaN
# 8757   US_Bill_Digest_115_sres_98.xml        2.0        4.0        NaN
# 8758   US_Bill_Digest_115_sres_99.xml        1.0        NaN        NaN
#
#       sentence3  sentence4                                           summary0  \
# 0           NaN        NaN                                                NaN
# 1           NaN        NaN                                                NaN
# 2           NaN        NaN                                                NaN
# 3           NaN        NaN                                                NaN
# 4           NaN        NaN                                                NaN
# 5           NaN        NaN                                                NaN
# 6           NaN        NaN                                                NaN
# 7           NaN        NaN                                                NaN
# 8           NaN        NaN                                                NaN
# 9           NaN        NaN                                                NaN
# 10          NaN        NaN                                                NaN
# 11          NaN        NaN                                                NaN
# 12          NaN        NaN                                                NaN
# 13          NaN        NaN                                                NaN
# 14          NaN        NaN                                                NaN
# 15          NaN        NaN                                                NaN
# 16          NaN        NaN                                                NaN
# 17          NaN        NaN                                                NaN
# 18          NaN        NaN                                                NaN
# 19          NaN        NaN                                                NaN
# 20          NaN        NaN                                                NaN
# 21          NaN        NaN                                                NaN
# 22          NaN        NaN                                                NaN
# 23          NaN        NaN                                                NaN
# 24          NaN        NaN                                                NaN
# 25          NaN        NaN  Probation Officer Protection Act of 2017 This ...
# 26          NaN        NaN  North Country National Scenic Trail Route Adju...
# 27          NaN        NaN  Provides amounts for expenses of the House Com...
# 28          NaN        NaN  Supports the designation of Darwin Day.  Recog...
# 29          NaN        NaN                                                NaN
# ...         ...        ...                                                ...
# 8729        NaN        NaN  Expresses the sense of the Senate that Jack Jo...
# 8730        NaN        NaN  Celebrates the history of the Detroit River wi...
# 8731        NaN        NaN  Designates February 28, 2017, as Rare Disease ...
# 8732        NaN        NaN  Congratulates Nebraska on the 150th anniversar...
# 8733        NaN        NaN   Commemorates October 20, 2017, as the 100th a...
# 8734        NaN        NaN  Supports the designation of March 21, 2017, as...
# 8735        NaN        NaN  Expresses support for the goals and ideals of ...
# 8736        NaN        NaN  Designates March 2, 2017, as Read Across Ameri...
# 8737        NaN        NaN  Designates the minority party membership on sp...
# 8738        NaN        NaN  Designates March 3, 2017, as World Wildlife Da...
# 8739        NaN        NaN  Congratulates the people of Greece as they cel...
# 8740        NaN        NaN  Congratulates the Johns Hopkins University App...
# 8741        NaN        NaN  Expresses the sense of the Senate that:   the ...
# 8742        NaN        NaN  Supports the goals of International Women's Da...
# 8743        NaN        NaN  Recognizes that March 9, 2017, marks 10 years ...
# 8744        NaN        NaN  Encourages the people of the United States to ...
# 8745        NaN        NaN  Condemns: (1) the regime of Bashar al-Assad fo...
# 8746        NaN        NaN  Expresses the sense of the Senate that: (1) th...
# 8747        NaN        NaN  Expresses support for the designation of March...
# 8748        NaN        NaN  Honors the life, leadership, and 70-year reign...
# 8749        NaN        NaN  Affirms that the U.S.-Israel economic partners...
# 8750        NaN        NaN  Supports the goals and ideals of National Prof...
# 8751        NaN        NaN  Expresses concern about the disappearance of D...
# 8752        NaN        NaN  Congratulates the European Union on the 60th a...
# 8753        NaN        NaN  Designates March 2017 as National Read Aloud M...
# 8754        NaN        NaN  Designates March 22, 2017, as National Rehabil...
# 8755        NaN        NaN  Designates March 25, 2017, as National Cerebra...
# 8756        NaN        NaN  Requires that a collection of the rules of the...
# 8757        NaN        NaN  Designates the first week of April 2017 as Nat...
# 8758        NaN        NaN  Recognizes the dedicated service and ultimate ...
#
#                                                summary1  ...  title72 title73  \
# 0                                                   NaN  ...      NaN     NaN
# 1                                                   NaN  ...      NaN     NaN
# 2                                                   NaN  ...      NaN     NaN
# 3                                                   NaN  ...      NaN     NaN
# 4                                                   NaN  ...      NaN     NaN
# 5                                                   NaN  ...      NaN     NaN
# 6                                                   NaN  ...      NaN     NaN
# 7                                                   NaN  ...      NaN     NaN
# 8                                                   NaN  ...      NaN     NaN
# 9                                                   NaN  ...      NaN     NaN
# 10                                                  NaN  ...      NaN     NaN
# 11                                                  NaN  ...      NaN     NaN
# 12                                                  NaN  ...      NaN     NaN
# 13                                                  NaN  ...      NaN     NaN
# 14                                                  NaN  ...      NaN     NaN
# 15                                                  NaN  ...      NaN     NaN
# 16                                                  NaN  ...      NaN     NaN
# 17                                                  NaN  ...      NaN     NaN
# 18                                                  NaN  ...      NaN     NaN
# 19                                                  NaN  ...      NaN     NaN
# 20                                                  NaN  ...      NaN     NaN
# 21                                                  NaN  ...      NaN     NaN
# 22                                                  NaN  ...      NaN     NaN
# 23                                                  NaN  ...      NaN     NaN
# 24                                                  NaN  ...      NaN     NaN
# 25                                                  NaN  ...      NaN     NaN
# 26                                                  NaN  ...      NaN     NaN
# 27                                                  NaN  ...      NaN     NaN
# 28                                                  NaN  ...      NaN     NaN
# 29                                                  NaN  ...      NaN     NaN
# ...                                                 ...  ...      ...     ...
# 8729                                                NaN  ...      NaN     NaN
# 8730                                                NaN  ...      NaN     NaN
# 8731  (This measure has not been amended since it wa...  ...      NaN     NaN
# 8732  (This measure has not been amended since it wa...  ...      NaN     NaN
# 8733                                                NaN  ...      NaN     NaN
# 8734  (This measure has not been amended since it wa...  ...      NaN     NaN
# 8735  (This measure has not been amended since it wa...  ...      NaN     NaN
# 8736  (This measure has not been amended since it wa...  ...      NaN     NaN
# 8737  (This measure has not been amended since it wa...  ...      NaN     NaN
# 8738  (This measure has not been amended since it wa...  ...      NaN     NaN
# 8739  (This measure has not been amended since it wa...  ...      NaN     NaN
# 8740  (This measure has not been amended since it wa...  ...      NaN     NaN
# 8741  (This measure has not been amended since it wa...  ...      NaN     NaN
# 8742  (This measure has not been amended since it wa...  ...      NaN     NaN
# 8743                                                NaN  ...      NaN     NaN
# 8744  (This measure has not been amended since it wa...  ...      NaN     NaN
# 8745                                                NaN  ...      NaN     NaN
# 8746                                                NaN  ...      NaN     NaN
# 8747  (This measure has not been amended since it wa...  ...      NaN     NaN
# 8748  (This measure has not been amended since it wa...  ...      NaN     NaN
# 8749                                                NaN  ...      NaN     NaN
# 8750                                                NaN  ...      NaN     NaN
# 8751                                                NaN  ...      NaN     NaN
# 8752                                                NaN  ...      NaN     NaN
# 8753  (This measure has not been amended since it wa...  ...      NaN     NaN
# 8754  (This measure has not been amended since it wa...  ...      NaN     NaN
# 8755  (This measure has not been amended since it wa...  ...      NaN     NaN
# 8756  (This measure has not been amended since it wa...  ...      NaN     NaN
# 8757  (This measure has not been amended since it wa...  ...      NaN     NaN
# 8758                                                NaN  ...      NaN     NaN
#
#      title74 title8 title9  word0  word1 word2 word3 word4
# 0        NaN    NaN    NaN    NaN    NaN   NaN   NaN   NaN
# 1        NaN    NaN    NaN    NaN    NaN   NaN   NaN   NaN
# 2        NaN    NaN    NaN    NaN    NaN   NaN   NaN   NaN
# 3        NaN    NaN    NaN    NaN    NaN   NaN   NaN   NaN
# 4        NaN    NaN    NaN    NaN    NaN   NaN   NaN   NaN
# 5        NaN    NaN    NaN    NaN    NaN   NaN   NaN   NaN
# 6        NaN    NaN    NaN    NaN    NaN   NaN   NaN   NaN
# 7        NaN    NaN    NaN    NaN    NaN   NaN   NaN   NaN
# 8        NaN    NaN    NaN    NaN    NaN   NaN   NaN   NaN
# 9        NaN    NaN    NaN    NaN    NaN   NaN   NaN   NaN
# 10       NaN    NaN    NaN    NaN    NaN   NaN   NaN   NaN
# 11       NaN    NaN    NaN    NaN    NaN   NaN   NaN   NaN
# 12       NaN    NaN    NaN    NaN    NaN   NaN   NaN   NaN
# 13       NaN    NaN    NaN    NaN    NaN   NaN   NaN   NaN
# 14       NaN    NaN    NaN    NaN    NaN   NaN   NaN   NaN
# 15       NaN    NaN    NaN    NaN    NaN   NaN   NaN   NaN
# 16       NaN    NaN    NaN    NaN    NaN   NaN   NaN   NaN
# 17       NaN    NaN    NaN    NaN    NaN   NaN   NaN   NaN
# 18       NaN    NaN    NaN    NaN    NaN   NaN   NaN   NaN
# 19       NaN    NaN    NaN    NaN    NaN   NaN   NaN   NaN
# 20       NaN    NaN    NaN    NaN    NaN   NaN   NaN   NaN
# 21       NaN    NaN    NaN    NaN    NaN   NaN   NaN   NaN
# 22       NaN    NaN    NaN    NaN    NaN   NaN   NaN   NaN
# 23       NaN    NaN    NaN    NaN    NaN   NaN   NaN   NaN
# 24       NaN    NaN    NaN    NaN    NaN   NaN   NaN   NaN
# 25       NaN    NaN    NaN   55.0    NaN   NaN   NaN   NaN
# 26       NaN    NaN    NaN   45.0    NaN   NaN   NaN   NaN
# 27       NaN    NaN    NaN   14.0    NaN   NaN   NaN   NaN
# 28       NaN    NaN    NaN   28.0    NaN   NaN   NaN   NaN
# 29       NaN    NaN    NaN    NaN    NaN   NaN   NaN   NaN
# ...      ...    ...    ...    ...    ...   ...   ...   ...
# 8729     NaN    NaN    NaN   59.0    NaN   NaN   NaN   NaN
# 8730     NaN    NaN    NaN   71.0    NaN   NaN   NaN   NaN
# 8731     NaN    NaN    NaN   28.0   46.0   NaN   NaN   NaN
# 8732     NaN    NaN    NaN   13.0   31.0   NaN   NaN   NaN
# 8733     NaN    NaN    NaN   39.0    NaN   NaN   NaN   NaN
# 8734     NaN    NaN    NaN   24.0   42.0   NaN   NaN   NaN
# 8735     NaN    NaN    NaN   76.0   94.0   NaN   NaN   NaN
# 8736     NaN    NaN    NaN   52.0   70.0   NaN   NaN   NaN
# 8737     NaN    NaN    NaN   13.0   31.0   NaN   NaN   NaN
# 8738     NaN    NaN    NaN   92.0  110.0   NaN   NaN   NaN
# 8739     NaN    NaN    NaN   53.0   71.0   NaN   NaN   NaN
# 8740     NaN    NaN    NaN   57.0   75.0   NaN   NaN   NaN
# 8741     NaN    NaN    NaN  163.0  181.0   NaN   NaN   NaN
# 8742     NaN    NaN    NaN  148.0  166.0   NaN   NaN   NaN
# 8743     NaN    NaN    NaN  156.0    NaN   NaN   NaN   NaN
# 8744     NaN    NaN    NaN   72.0   90.0   NaN   NaN   NaN
# 8745     NaN    NaN    NaN  316.0    NaN   NaN   NaN   NaN
# 8746     NaN    NaN    NaN   86.0    NaN   NaN   NaN   NaN
# 8747     NaN    NaN    NaN   14.0   32.0   NaN   NaN   NaN
# 8748     NaN    NaN    NaN   62.0   80.0   NaN   NaN   NaN
# 8749     NaN    NaN    NaN   89.0    NaN   NaN   NaN   NaN
# 8750     NaN    NaN    NaN   23.0    NaN   NaN   NaN   NaN
# 8751     NaN    NaN    NaN  126.0    NaN   NaN   NaN   NaN
# 8752     NaN    NaN    NaN   74.0    NaN   NaN   NaN   NaN
# 8753     NaN    NaN    NaN   32.0   50.0   NaN   NaN   NaN
# 8754     NaN    NaN    NaN   21.0   39.0   NaN   NaN   NaN
# 8755     NaN    NaN    NaN   10.0   28.0   NaN   NaN   NaN
# 8756     NaN    NaN    NaN   34.0   52.0   NaN   NaN   NaN
# 8757     NaN    NaN    NaN   31.0   49.0   NaN   NaN   NaN
# 8758     NaN    NaN    NaN   45.0    NaN   NaN   NaN   NaN
#
# [8759 rows x 94 columns]
